# %% [markdown]
# # <font style="color:blue">Table of Content</font>
#
#
#
# - [1. Training Utils](#utils)
# - [2. Model 1: Small Model [S]](#small-model)
# - [2.1. Experiment 1: Without Regularization [S]](#S-without)
# - [3. Model 2: Medium Model [M]](#medium)
# - [3.1. Experiment 2: Without Regularization [M]](#M-without)
# - [3.2. Experiment 3: With Batch-Norm [M]](#M-with_BN)
# - [3.3 Experiment 4: With Dropout [M]](#M-with_Drop)
# - [3.4. Experiment 5: With Batch-Norm and Dropout [M]](#M-with_B_and_Drop)
# - [3.5. Experiment 6: Data Augmentation [M]](#M-with_aug)
# - [3.6. Experiment 7: Data Augmentation with Batch-Norm and Dropout [M]](#M-with_Aug_and_BN_and_Drop)
# - [4. Model 3: Large Model [L]](#Large)
# - [4.1. Experiment 8: Data Augmentation With Batch-Norm and Dropout [L]](#L-with_Drop_Aug_BN)
# - [5. Loss and Accuracy Plot of All Experiments](#plots)
# - [6. Conclusion](#conclusion)
# - [Exercise](#exercise)

# %% [markdown]
# # <font style="color:blue">Training With Regularization</font>
#
# We have already covered the theory of bias, variance, and different regularization techniques.
#
# In this notebook, you will learn  to use these concepts to improve our model. Techniques used:
#
# 1. Batch-Norm
#
#
# 2. Dropout
#
#
# 3. Data augmentation
#
# We will illustrate the different techniques using the "Fashion MNIST" dataset and the `LambdaLR` scheduler with `SGD`.
#
# **We will experiment with the following:**
#
# 1. **A Small Model:** Start with a small CNN (**`SmallModel` \[S\]**), which reaches an accuracy of around `90%`. Note that even the training accuracy is not very high. It means that the LeNet model is not complex enough to overfit (get almost 100% accuracy on training data, or around zero loss on training data). Going by the definition of bias and variance, this model has high bias and variance.
#
#
# 2. **A Larger Model:** So,we need a deeper and wider model. Accordingly, we create one bigger model (**`MediumModel` \[M\]**). Also, in order to conduct all our  experiments, this model has to be configurable. Such that we can specify options for `Dropout/Batch Norm` etc.
#
#
# 3. **Without any Regularization:** First, try the `MediumModel` without any regularization (no Dropout,  Batch Norm, Data augmentation or L2-penalty). We find that that model overfits (around `100 %` training accuracy, but only `92-93 %` for validation). This model has low bias and high variance. We therefore need to use   regularization techniques to reduce this high variance.
#
#
# 4. **With Batch Normalization:** Start with Batch Norm regularization. You will notice that the accuracy improves slightly. Also, the  loss decreases. Even if accuracy does not improve and only the loss decreases, it still means this is a more robust model (misclassification confidence will not be very high).
#
#
# 5. **With Dropout Regularization:** Explore Dropout, without Batch norm. You find that with the Dropout, accuracy remains almost the same but loss improves.
#
#
# 6. **With combined Dropout and Batch Norm:** Now, consider Batch Norm with Dropout. In terms of accuracy and loss, these cases turn out to be slightly better than the ones above.,when we measure.
#
#
# 7. **With Data Augmentation:** Next, explore the Data augmentation technique. Start without Batch  Norm or Dropout. Implemented alone, Data augmentation turns out to be better than all the above techniques. Why is it so? That’s because it is a virtual way to increase the number of training data, which in turn, helps in model generalization.
#
#
# 8. **With all three techniques:** Now, try using both Batch Norm and Dropout with Data augmentation. It  works better than all the above. At the same time, you will notice that train loss  decreases till the last epoch (60 epoch), but is higher than the validation loss, although validation loss is not decreasing. This means there is no point increasing the total number of epochs, The validation loss is unlikely to decrease.
#
#
# 9. **With an even Larger Model:** Let’s now create one complex model ((**LargeModel \[L\]**, by increasing the number of filters) and explore Data augmentation along with Batch Norm and Dropout. This turns out to be the best technique.

# %% [markdown]
# # <font style="color:blue">1. Training Utils</font><a name="utils"></a>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt  # one of the best graphics library for python
plt.style.use('ggplot')

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, transforms

from torch.optim import lr_scheduler

# %% [markdown]
# ## <font style="color:green">1.1. Fashion MNIST Data With Optional Data Augmentation</font>
#
#
# You already know the `get_data` method. Now, modify this method to generate augmented data. Use the `data_augmentation` argument to switch on-off the augmentation.
#
#
# For Data Augmentation, do the following:
#
# - Random Horizontal Flip
#
#
# - Random Vertical Flip
#
#
# - Random Rotation

# %%
def get_data(batch_size, data_root='data', num_workers=1, data_augmentation=False):
    
    # common transforms
    common_transforms = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.2860, ), (0.3530, ))
    ])
    
    # if data_augmentation is true 
    # data augmentation implementation
    if data_augmentation:
        train_transforms = transforms.Compose([
            transforms.RandomChoice([
                transforms.RandomHorizontalFlip(),
                transforms.RandomVerticalFlip(),
                transforms.RandomRotation(20, fill=(0,)),
                transforms.RandomCrop(28, padding=4)
            ]),
            transforms.ToTensor(),
            transforms.Normalize((0.2860, ), (0.3530, ))
        ])
    # else do common transforms
    else:
        train_transforms = common_transforms
        
        
    
    # train dataloader
    train_loader = torch.utils.data.DataLoader(
        datasets.FashionMNIST(root=data_root, train=True, download=True, transform=train_transforms),
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers
    )
    
    # test dataloader
    test_loader = torch.utils.data.DataLoader(
        datasets.FashionMNIST(root=data_root, train=False, download=True, transform=common_transforms),
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers
    )
    return train_loader, test_loader

# %% [markdown]
# ## <font style="color:green">1.2. System Configuration</font>

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ## <font style="color:green">1.3. Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 32  
    epochs_count: int = 60
    init_learning_rate: float = 0.02  # initial learning rate for lr scheduler
    decay_rate: float = 0.1  
    log_interval: int = 500  
    test_interval: int = 1  
    data_root: str = "./data" 
    num_workers: int = 10  
    device: str = 'cuda'

# %% [markdown]
# ## <font style="color:green">1.4. System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:green">1.5. Training Function</font>
#
# You are familiar with the training pipeline used in PyTorch.

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int
) -> None:
    
    # change model in training mode
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (it is mandatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = F.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gradients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # get probability score using softmax
        prob = F.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])

#         if batch_idx % train_config.log_interval == 0 and batch_idx > 0:              
#             print(
#                 'Train Epoch: {} [{}/{}] Loss: {:.6f} Acc: {:.4f}'.format(
#                     epoch_idx, batch_idx * len(data), len(train_loader.dataset), loss.item(), acc
#                 )
#             )
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    print('Epoch: {} Train Loss: {:.6f} Acc: {:.4f}'.format(
                epoch_idx, epoch_loss, epoch_acc))
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:green">1.6. Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader,
) -> float:
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        output = model(data)
        # add loss for each mini batch
        test_loss += F.cross_entropy(output, target).item()
        
        # get probability score using softmax
        prob = F.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:green">1.7. Main Function for Training and Validation</font>
#
# For this, use the configuration parameters defined above, and start training. Action points in the code below:
#
# 1. Set up system parameters like CPU/GPU, number of threads etc.
#
#
# 2. Load the data using dataloaders.
#
#
# 3. For each epoch, call  the train function. For every test interval, call validation.
#
#
#
# 4. Do `scheduler.step()` to update the learning rate for next epoch.
#
#
# 5. Set up variables to track loss and accuracy and start training.

# %%
def main(model, optimizer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=False):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lower batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
        batch_size_to_set = 16
        num_workers_to_set = 2

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        data_root=training_configuration.data_root,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epoch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # training time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            if current_loss < best_loss:
                best_loss = current_loss
        
        # scheduler step/ update learning rate
        if scheduler is not None:
            scheduler.step()
        
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:green">1.8. Optimizer and Scheduler</font>
#
# Let's write optimizer and scheduler as a method because we have to use it in all training experiments.

# %%
def get_optimizer_and_scheduler(model):
    train_config = TrainingConfiguration()

    init_learning_rate = train_config.init_learning_rate

    # optimizer
    optimizer = optim.SGD(
        model.parameters(),
        lr = init_learning_rate,
        momentum = 0.9
    )

    decay_rate = train_config.decay_rate

    lmbda = lambda epoch: 1/(1 + decay_rate * epoch)

    # Scheduler
    scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lmbda)
    
    return optimizer, scheduler

# %% [markdown]
# ## <font style="color:green">1.9. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, labels, colors, model_sizes, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', legend_font=15,
                       fig_size=(16, 8), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    plt.figure
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="[{2}] TRAIN ({0:.4}): {1}".format(min_train_loss, labels[i], model_sizes[i]))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="[{2}] VALID ({0:.4}): {1}".format(min_val_loss, labels[i], model_sizes[i]))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc, prop={'size': legend_font})
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="[{2}] TRAIN ({0:.4}): {1}".format(max_train_acc, labels[i], model_sizes[i]))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="[{2}] VALID ({0:.4}): {1}".format(max_val_acc, labels[i], model_sizes[i]))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc, prop={'size': legend_font})
    plt.title('Training and Validation Accuracy')
    
    plt.show()
    
    return

# %% [markdown]
# # <font style="color:blue">2. Model 1: Small Model [S]</font> <a name="small-model"></a>
#
# A smaller model compared to the `LeNet` Network, let’s check out how much it can learn!

# %%
class SmallModel(nn.Module):
    def __init__(self):
        super().__init__()

        # convolution layers
        self._body = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=4, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            
            nn.Conv2d(in_channels=4, out_channels=8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )
        
        # Fully connected layers
        self._head = nn.Sequential(
            
            nn.Linear(in_features=8 * 5 * 5, out_features=100), 
            nn.ReLU(inplace=True),
            
            nn.Linear(in_features=100, out_features=50), 
            nn.ReLU(inplace=True),
            
            nn.Linear(in_features=50, out_features=10)
        )

    def forward(self, x):
        x = self._body(x)
        x = x.view(x.size()[0], -1)
        x = self._head(x)
        return x

# %% [markdown]
# ## <font style="color:green">2.1. Experiment 1: Without Regularization [S]</font><a name="S-without"></a>

# %%
model = SmallModel()
print(model)

# get optimizer and scheduler
optimizer, scheduler = get_optimizer_and_scheduler(model)

# train and validate
model, train_loss_exp1, train_acc_exp1, val_loss_exp1, val_acc_exp1 = main(model, 
                                                                           optimizer, 
                                                                           scheduler)
# Out:
# SmallModel(
#   (_body): Sequential(
#     (0): Conv2d(1, 4, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (_head): Sequential(
#     (0): Linear(in_features=200, out_features=100, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=100, out_features=50, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=50, out_features=10, bias=True)
#   )
# )
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data\FashionMNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:04<00:00, 6511393.47it/s]
# Extracting ./data\FashionMNIST\raw\train-images-idx3-ubyte.gz to ./data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data\FashionMNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 1791402.69it/s]
# Extracting ./data\FashionMNIST\raw\train-labels-idx1-ubyte.gz to ./data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 5108869.99it/s]
# Extracting ./data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz to ./data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<?, ?it/s]
# Extracting ./data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz to ./data\FashionMNIST\raw
# Epoch: 0 Train Loss: 0.581558 Acc: 0.7860
# Elapsed 21.72s, 21.72 s/epoch, 0.01 s/batch, ets 1281.76s
#
# Test set: Average loss: 0.5072, Accuracy: 8199/10000 (82%)
#
# Epoch: 1 Train Loss: 0.431861 Acc: 0.8408
# Elapsed 48.59s, 24.30 s/epoch, 0.01 s/batch, ets 1409.22s
#
# Test set: Average loss: 0.4457, Accuracy: 8313/10000 (83%)
#
# Epoch: 2 Train Loss: 0.397089 Acc: 0.8529
# Elapsed 75.03s, 25.01 s/epoch, 0.01 s/batch, ets 1425.62s
#
# Test set: Average loss: 0.4090, Accuracy: 8477/10000 (85%)
#
# Epoch: 3 Train Loss: 0.369694 Acc: 0.8634
# Elapsed 101.16s, 25.29 s/epoch, 0.01 s/batch, ets 1416.30s
#
# Test set: Average loss: 0.3844, Accuracy: 8559/10000 (86%)
#
# Epoch: 4 Train Loss: 0.351130 Acc: 0.8723
# Elapsed 127.88s, 25.58 s/epoch, 0.01 s/batch, ets 1406.71s
#
# Test set: Average loss: 0.4026, Accuracy: 8576/10000 (86%)
#
# Epoch: 5 Train Loss: 0.334763 Acc: 0.8771
# Elapsed 154.76s, 25.79 s/epoch, 0.01 s/batch, ets 1392.80s
#
# Test set: Average loss: 0.3641, Accuracy: 8724/10000 (87%)
#
# Epoch: 6 Train Loss: 0.322463 Acc: 0.8801
# Elapsed 181.53s, 25.93 s/epoch, 0.01 s/batch, ets 1374.47s
#
# Test set: Average loss: 0.3788, Accuracy: 8653/10000 (87%)
#
# Epoch: 7 Train Loss: 0.309584 Acc: 0.8853
# Elapsed 207.99s, 26.00 s/epoch, 0.01 s/batch, ets 1351.94s
#
# Test set: Average loss: 0.3469, Accuracy: 8757/10000 (88%)
#
# Epoch: 8 Train Loss: 0.295239 Acc: 0.8885
# Elapsed 233.94s, 25.99 s/epoch, 0.01 s/batch, ets 1325.68s
#
# Test set: Average loss: 0.3452, Accuracy: 8769/10000 (88%)
#
# Epoch: 9 Train Loss: 0.285971 Acc: 0.8923
# Elapsed 260.54s, 26.05 s/epoch, 0.01 s/batch, ets 1302.72s
#
# Test set: Average loss: 0.3616, Accuracy: 8741/10000 (87%)
#
# Epoch: 10 Train Loss: 0.275688 Acc: 0.8963
# Elapsed 287.24s, 26.11 s/epoch, 0.01 s/batch, ets 1279.50s
#
# Test set: Average loss: 0.3341, Accuracy: 8801/10000 (88%)
#
# Epoch: 11 Train Loss: 0.271473 Acc: 0.8983
# Elapsed 314.06s, 26.17 s/epoch, 0.01 s/batch, ets 1256.22s
#
# Test set: Average loss: 0.3421, Accuracy: 8773/10000 (88%)
#
# Epoch: 12 Train Loss: 0.265637 Acc: 0.8987
# Elapsed 341.08s, 26.24 s/epoch, 0.01 s/batch, ets 1233.12s
#
# Test set: Average loss: 0.3515, Accuracy: 8797/10000 (88%)
#
# Epoch: 13 Train Loss: 0.257183 Acc: 0.9022
# Elapsed 368.79s, 26.34 s/epoch, 0.01 s/batch, ets 1211.74s
#
# Test set: Average loss: 0.3459, Accuracy: 8768/10000 (88%)
#
# Epoch: 14 Train Loss: 0.247795 Acc: 0.9055
# Elapsed 396.02s, 26.40 s/epoch, 0.01 s/batch, ets 1188.06s
#
# Test set: Average loss: 0.3553, Accuracy: 8797/10000 (88%)
#
# Epoch: 15 Train Loss: 0.243068 Acc: 0.9064
# Elapsed 423.13s, 26.45 s/epoch, 0.01 s/batch, ets 1163.60s
#
# Test set: Average loss: 0.3445, Accuracy: 8846/10000 (88%)
#
# Epoch: 16 Train Loss: 0.236965 Acc: 0.9095
# Elapsed 450.90s, 26.52 s/epoch, 0.01 s/batch, ets 1140.50s
#
# Test set: Average loss: 0.3478, Accuracy: 8853/10000 (89%)
#
# Epoch: 17 Train Loss: 0.231102 Acc: 0.9116
# Elapsed 478.68s, 26.59 s/epoch, 0.01 s/batch, ets 1116.92s
#
# Test set: Average loss: 0.3487, Accuracy: 8820/10000 (88%)
#
# Epoch: 18 Train Loss: 0.222362 Acc: 0.9136
# Elapsed 506.37s, 26.65 s/epoch, 0.01 s/batch, ets 1092.70s
#
# Test set: Average loss: 0.3503, Accuracy: 8818/10000 (88%)
#
# Epoch: 19 Train Loss: 0.217792 Acc: 0.9155
# Elapsed 533.91s, 26.70 s/epoch, 0.01 s/batch, ets 1067.82s
#
# Test set: Average loss: 0.3556, Accuracy: 8820/10000 (88%)
#
# Epoch: 20 Train Loss: 0.215171 Acc: 0.9163
# Elapsed 560.82s, 26.71 s/epoch, 0.01 s/batch, ets 1041.52s
#
# Test set: Average loss: 0.3470, Accuracy: 8869/10000 (89%)
#
# Epoch: 21 Train Loss: 0.211763 Acc: 0.9180
# Elapsed 588.07s, 26.73 s/epoch, 0.01 s/batch, ets 1015.76s
#
# Test set: Average loss: 0.3489, Accuracy: 8877/10000 (89%)
#
# Epoch: 22 Train Loss: 0.204466 Acc: 0.9211
# Elapsed 614.22s, 26.71 s/epoch, 0.01 s/batch, ets 988.10s
#
# Test set: Average loss: 0.3624, Accuracy: 8877/10000 (89%)
#
# Epoch: 23 Train Loss: 0.200624 Acc: 0.9225
# Elapsed 640.71s, 26.70 s/epoch, 0.01 s/batch, ets 961.06s
#
# Test set: Average loss: 0.3546, Accuracy: 8823/10000 (88%)
#
# Epoch: 24 Train Loss: 0.194100 Acc: 0.9256
# Elapsed 667.09s, 26.68 s/epoch, 0.01 s/batch, ets 933.93s
#
# Test set: Average loss: 0.3617, Accuracy: 8895/10000 (89%)
#
# Epoch: 25 Train Loss: 0.191197 Acc: 0.9258
# Elapsed 693.38s, 26.67 s/epoch, 0.01 s/batch, ets 906.73s
#
# Test set: Average loss: 0.3905, Accuracy: 8795/10000 (88%)
#
# Epoch: 26 Train Loss: 0.185811 Acc: 0.9259
# Elapsed 719.83s, 26.66 s/epoch, 0.01 s/batch, ets 879.79s
#
# Test set: Average loss: 0.3656, Accuracy: 8888/10000 (89%)
#
# Epoch: 27 Train Loss: 0.186028 Acc: 0.9273
# Elapsed 745.95s, 26.64 s/epoch, 0.01 s/batch, ets 852.51s
#
# Test set: Average loss: 0.3724, Accuracy: 8867/10000 (89%)
#
# Epoch: 28 Train Loss: 0.179043 Acc: 0.9300
# Elapsed 772.28s, 26.63 s/epoch, 0.01 s/batch, ets 825.54s
#
# Test set: Average loss: 0.3954, Accuracy: 8887/10000 (89%)
#
# Epoch: 29 Train Loss: 0.175101 Acc: 0.9313
# Elapsed 800.34s, 26.68 s/epoch, 0.01 s/batch, ets 800.34s
#
# Test set: Average loss: 0.3940, Accuracy: 8881/10000 (89%)
#
# Epoch: 30 Train Loss: 0.173852 Acc: 0.9311
# Elapsed 828.13s, 26.71 s/epoch, 0.01 s/batch, ets 774.70s
#
# Test set: Average loss: 0.3940, Accuracy: 8889/10000 (89%)
#
# Epoch: 31 Train Loss: 0.166728 Acc: 0.9337
# Elapsed 855.14s, 26.72 s/epoch, 0.01 s/batch, ets 748.25s
#
# Test set: Average loss: 0.3932, Accuracy: 8888/10000 (89%)
#
# Epoch: 32 Train Loss: 0.162707 Acc: 0.9361
# Elapsed 881.32s, 26.71 s/epoch, 0.01 s/batch, ets 721.08s
#
# Test set: Average loss: 0.4225, Accuracy: 8855/10000 (89%)
#
# Epoch: 33 Train Loss: 0.162603 Acc: 0.9353
# Elapsed 907.56s, 26.69 s/epoch, 0.01 s/batch, ets 694.02s
#
# Test set: Average loss: 0.4284, Accuracy: 8878/10000 (89%)
#
# Epoch: 34 Train Loss: 0.160426 Acc: 0.9363
# Elapsed 933.95s, 26.68 s/epoch, 0.01 s/batch, ets 667.10s
#
# Test set: Average loss: 0.4428, Accuracy: 8896/10000 (89%)
#
# Epoch: 35 Train Loss: 0.161514 Acc: 0.9362
# Elapsed 960.18s, 26.67 s/epoch, 0.01 s/batch, ets 640.12s
#
# Test set: Average loss: 0.4314, Accuracy: 8876/10000 (89%)
#
# Epoch: 36 Train Loss: 0.156636 Acc: 0.9371
# Elapsed 986.24s, 26.66 s/epoch, 0.01 s/batch, ets 613.07s
#
# Test set: Average loss: 0.4518, Accuracy: 8831/10000 (88%)
#
# Epoch: 37 Train Loss: 0.153709 Acc: 0.9396
# Elapsed 1011.98s, 26.63 s/epoch, 0.01 s/batch, ets 585.88s
#
# Test set: Average loss: 0.4527, Accuracy: 8872/10000 (89%)
#
# Epoch: 38 Train Loss: 0.147306 Acc: 0.9414
# Elapsed 1038.31s, 26.62 s/epoch, 0.01 s/batch, ets 559.09s
#
# Test set: Average loss: 0.4427, Accuracy: 8866/10000 (89%)
#
# Epoch: 39 Train Loss: 0.143526 Acc: 0.9428
# Elapsed 1064.11s, 26.60 s/epoch, 0.01 s/batch, ets 532.05s
#
# Test set: Average loss: 0.4550, Accuracy: 8885/10000 (89%)
#
# Epoch: 40 Train Loss: 0.145059 Acc: 0.9417
# Elapsed 1091.55s, 26.62 s/epoch, 0.01 s/batch, ets 505.84s
#
# Test set: Average loss: 0.4751, Accuracy: 8853/10000 (89%)
#
# Epoch: 41 Train Loss: 0.140276 Acc: 0.9437
# Elapsed 1119.02s, 26.64 s/epoch, 0.01 s/batch, ets 479.58s
#
# Test set: Average loss: 0.4824, Accuracy: 8845/10000 (88%)
#
# Epoch: 42 Train Loss: 0.139895 Acc: 0.9444
# Elapsed 1145.43s, 26.64 s/epoch, 0.01 s/batch, ets 452.84s
#
# Test set: Average loss: 0.4898, Accuracy: 8840/10000 (88%)
#
# Epoch: 43 Train Loss: 0.136045 Acc: 0.9453
# Elapsed 1171.73s, 26.63 s/epoch, 0.01 s/batch, ets 426.08s
#
# Test set: Average loss: 0.4806, Accuracy: 8868/10000 (89%)
#
# Epoch: 44 Train Loss: 0.132793 Acc: 0.9476
# Elapsed 1198.34s, 26.63 s/epoch, 0.01 s/batch, ets 399.45s
#
# Test set: Average loss: 0.5234, Accuracy: 8862/10000 (89%)
#
# Epoch: 45 Train Loss: 0.129452 Acc: 0.9490
# Elapsed 1224.85s, 26.63 s/epoch, 0.01 s/batch, ets 372.78s
#
# Test set: Average loss: 0.5233, Accuracy: 8851/10000 (89%)
#
# Epoch: 46 Train Loss: 0.129319 Acc: 0.9493
# Elapsed 1251.38s, 26.63 s/epoch, 0.01 s/batch, ets 346.13s
#
# Test set: Average loss: 0.5137, Accuracy: 8829/10000 (88%)
#
# Epoch: 47 Train Loss: 0.127919 Acc: 0.9495
# Elapsed 1278.29s, 26.63 s/epoch, 0.01 s/batch, ets 319.57s
#
# Test set: Average loss: 0.5266, Accuracy: 8828/10000 (88%)
#
# Epoch: 48 Train Loss: 0.124292 Acc: 0.9504
# Elapsed 1305.44s, 26.64 s/epoch, 0.01 s/batch, ets 293.06s
#
# Test set: Average loss: 0.5338, Accuracy: 8853/10000 (89%)
#
# Epoch: 49 Train Loss: 0.122931 Acc: 0.9515
# Elapsed 1332.70s, 26.65 s/epoch, 0.01 s/batch, ets 266.54s
#
# Test set: Average loss: 0.5582, Accuracy: 8801/10000 (88%)
#
# Epoch: 50 Train Loss: 0.117627 Acc: 0.9524
# Elapsed 1359.55s, 26.66 s/epoch, 0.01 s/batch, ets 239.92s
#
# Test set: Average loss: 0.5526, Accuracy: 8855/10000 (89%)
#
# Epoch: 51 Train Loss: 0.117574 Acc: 0.9533
# Elapsed 1385.75s, 26.65 s/epoch, 0.01 s/batch, ets 213.19s
#
# Test set: Average loss: 0.5687, Accuracy: 8825/10000 (88%)
#
# Epoch: 52 Train Loss: 0.116500 Acc: 0.9528
# Elapsed 1412.64s, 26.65 s/epoch, 0.01 s/batch, ets 186.58s
#
# Test set: Average loss: 0.5786, Accuracy: 8824/10000 (88%)
#
# Epoch: 53 Train Loss: 0.112614 Acc: 0.9552
# Elapsed 1439.74s, 26.66 s/epoch, 0.01 s/batch, ets 159.97s
#
# Test set: Average loss: 0.6007, Accuracy: 8847/10000 (88%)
#
# Epoch: 54 Train Loss: 0.113059 Acc: 0.9550
# Elapsed 1466.28s, 26.66 s/epoch, 0.01 s/batch, ets 133.30s
#
# Test set: Average loss: 0.6001, Accuracy: 8841/10000 (88%)
#
# Epoch: 55 Train Loss: 0.109410 Acc: 0.9564
# Elapsed 1492.78s, 26.66 s/epoch, 0.01 s/batch, ets 106.63s
#
# Test set: Average loss: 0.6223, Accuracy: 8867/10000 (89%)
#
# Epoch: 56 Train Loss: 0.111347 Acc: 0.9548
# Elapsed 1519.43s, 26.66 s/epoch, 0.01 s/batch, ets 79.97s
#
# Test set: Average loss: 0.6396, Accuracy: 8825/10000 (88%)
#
# Epoch: 57 Train Loss: 0.108033 Acc: 0.9576
# Elapsed 1546.01s, 26.66 s/epoch, 0.01 s/batch, ets 53.31s
#
# Test set: Average loss: 0.6108, Accuracy: 8806/10000 (88%)
#
# Epoch: 58 Train Loss: 0.110763 Acc: 0.9557
# Elapsed 1572.64s, 26.65 s/epoch, 0.01 s/batch, ets 26.65s
#
# Test set: Average loss: 0.6321, Accuracy: 8873/10000 (89%)
#
# Epoch: 59 Train Loss: 0.102720 Acc: 0.9594
# Elapsed 1599.16s, 26.65 s/epoch, 0.01 s/batch, ets 0.00s
#
# Test set: Average loss: 0.6510, Accuracy: 8881/10000 (89%)
#
# Total time: 1604.14, Best Loss: 0.334

# %%
plot_loss_accuracy(train_loss=[train_loss_exp1], 
                   val_loss=[val_loss_exp1], 
                   train_acc=[train_acc_exp1], 
                   val_acc=[val_acc_exp1], 
                   labels=['No Reg'], 
                   colors=['blue'], 
                   model_sizes=['S'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# You can see that it has almost reached its learning capacity and starts overfitting, if when we continue training it.

# %% [markdown]
# # <font style="color:blue">3. Model 2: Medium Model [M]</font><a name="medium"></a>
#
# This is a larger model `MediumModel`.  You can use `dropout` or `batch-norm` or both. Just specify. Use this network to see the effects of overfitting and regularization.

# %%
class MediumModel(nn.Module):
    def __init__(self, dropout=0.0, batch_norm=False):
        super().__init__()

        # convolution layers
        if batch_norm:
            self._body = nn.Sequential(
                nn.Conv2d(in_channels=1, out_channels=16, kernel_size=5),
                nn.BatchNorm2d(16),
                nn.ReLU(inplace=True),

                nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5),
                nn.BatchNorm2d(32),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2),

                nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
                nn.BatchNorm2d(64),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2),
                nn.Dropout(dropout)
            )
        else:
             self._body = nn.Sequential(
                nn.Conv2d(in_channels=1, out_channels=16, kernel_size=5),
                nn.ReLU(inplace=True),

                nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2),

                nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2),
                nn.Dropout(dropout)
            )
            
        
        # Fully connected layers
        self._head = nn.Sequential(
            
            nn.Linear(in_features=64 * 4 * 4, out_features=512), 
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            
            nn.Linear(in_features=512, out_features=128), 
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            
            nn.Linear(in_features=128, out_features=10)
        )

    def forward(self, x):
        x = self._body(x)
        x = x.view(x.size()[0], -1)
        x = self._head(x)
        return x

# %% [markdown]
# ## <font style="color:green">3.1. Experiment 2: Without Regularization [M]</font><a name="M-without"></a>

# %%
model = MediumModel()
print(model)

# get optimizer and scheduler
optimizer, scheduler = get_optimizer_and_scheduler(model)

# train and validate
model, train_loss_exp2, train_acc_exp2, val_loss_exp2, val_acc_exp2 = main(model, 
                                                                           optimizer, 
                                                                           scheduler)
# Out:
# MediumModel(
#   (_body): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Dropout(p=0.0, inplace=False)
#   )
#   (_head): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=512, out_features=128, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# Epoch: 0 Train Loss: 0.529089 Acc: 0.8040
# Elapsed 41.96s, 41.96 s/epoch, 0.01 s/batch, ets 2475.67s
#
# Test set: Average loss: 0.3794, Accuracy: 8625/10000 (86%)
#
# Epoch: 1 Train Loss: 0.352455 Acc: 0.8694
# Elapsed 92.52s, 46.26 s/epoch, 0.01 s/batch, ets 2682.94s
#
# Test set: Average loss: 0.3566, Accuracy: 8608/10000 (86%)
#
# Epoch: 2 Train Loss: 0.307395 Acc: 0.8849
# Elapsed 141.98s, 47.33 s/epoch, 0.01 s/batch, ets 2697.61s
#
# Test set: Average loss: 0.3325, Accuracy: 8750/10000 (88%)
#
# Epoch: 3 Train Loss: 0.270146 Acc: 0.8987
# Elapsed 191.74s, 47.93 s/epoch, 0.01 s/batch, ets 2684.36s
#
# Test set: Average loss: 0.2940, Accuracy: 8903/10000 (89%)
#
# Epoch: 4 Train Loss: 0.244949 Acc: 0.9073
# Elapsed 241.67s, 48.33 s/epoch, 0.01 s/batch, ets 2658.41s
#
# Test set: Average loss: 0.3005, Accuracy: 8964/10000 (90%)
#
# Epoch: 5 Train Loss: 0.225322 Acc: 0.9151
# Elapsed 291.70s, 48.62 s/epoch, 0.01 s/batch, ets 2625.32s
#
# Test set: Average loss: 0.2961, Accuracy: 8958/10000 (90%)
#
# Epoch: 6 Train Loss: 0.203199 Acc: 0.9223
# Elapsed 340.58s, 48.65 s/epoch, 0.01 s/batch, ets 2578.69s
#
# Test set: Average loss: 0.2927, Accuracy: 8970/10000 (90%)
#
# Epoch: 7 Train Loss: 0.189140 Acc: 0.9286
# Elapsed 390.68s, 48.83 s/epoch, 0.01 s/batch, ets 2539.42s
#
# Test set: Average loss: 0.3159, Accuracy: 9040/10000 (90%)
#
# Epoch: 8 Train Loss: 0.171543 Acc: 0.9353
# Elapsed 439.06s, 48.78 s/epoch, 0.01 s/batch, ets 2488.02s
#
# Test set: Average loss: 0.3122, Accuracy: 9068/10000 (91%)
#
# Epoch: 9 Train Loss: 0.156655 Acc: 0.9391
# Elapsed 487.38s, 48.74 s/epoch, 0.01 s/batch, ets 2436.90s
#
# Test set: Average loss: 0.3985, Accuracy: 8895/10000 (89%)
#
# Epoch: 10 Train Loss: 0.147155 Acc: 0.9447
# Elapsed 535.93s, 48.72 s/epoch, 0.01 s/batch, ets 2387.34s
#
# Test set: Average loss: 0.3503, Accuracy: 8965/10000 (90%)
#
# Epoch: 11 Train Loss: 0.131093 Acc: 0.9504
# Elapsed 592.21s, 49.35 s/epoch, 0.01 s/batch, ets 2368.84s
#
# Test set: Average loss: 0.3462, Accuracy: 9052/10000 (91%)
#
# Epoch: 12 Train Loss: 0.120000 Acc: 0.9539
# Elapsed 644.24s, 49.56 s/epoch, 0.01 s/batch, ets 2329.18s
#
# Test set: Average loss: 0.3522, Accuracy: 9046/10000 (90%)
#
# Epoch: 13 Train Loss: 0.107112 Acc: 0.9593
# Elapsed 695.81s, 49.70 s/epoch, 0.01 s/batch, ets 2286.22s
#
# Test set: Average loss: 0.3745, Accuracy: 9078/10000 (91%)
#
# Epoch: 14 Train Loss: 0.099453 Acc: 0.9621
# Elapsed 746.60s, 49.77 s/epoch, 0.01 s/batch, ets 2239.80s
#
# Test set: Average loss: 0.3860, Accuracy: 9034/10000 (90%)
#
# Epoch: 15 Train Loss: 0.091940 Acc: 0.9650
# Elapsed 797.90s, 49.87 s/epoch, 0.01 s/batch, ets 2194.22s
#
# Test set: Average loss: 0.4032, Accuracy: 9020/10000 (90%)
#
# Epoch: 16 Train Loss: 0.085567 Acc: 0.9679
# Elapsed 849.35s, 49.96 s/epoch, 0.01 s/batch, ets 2148.36s
#
# Test set: Average loss: 0.4555, Accuracy: 8997/10000 (90%)
#
# Epoch: 17 Train Loss: 0.074608 Acc: 0.9725
# Elapsed 902.74s, 50.15 s/epoch, 0.01 s/batch, ets 2106.40s
#
# Test set: Average loss: 0.4672, Accuracy: 9002/10000 (90%)
#
# Epoch: 18 Train Loss: 0.070889 Acc: 0.9739
# Elapsed 956.21s, 50.33 s/epoch, 0.01 s/batch, ets 2063.39s
#
# Test set: Average loss: 0.4714, Accuracy: 9028/10000 (90%)
#
# Epoch: 19 Train Loss: 0.064008 Acc: 0.9765
# Elapsed 1009.51s, 50.48 s/epoch, 0.01 s/batch, ets 2019.02s
#
# Test set: Average loss: 0.4581, Accuracy: 9013/10000 (90%)
#
# Epoch: 20 Train Loss: 0.060513 Acc: 0.9778
# Elapsed 1061.96s, 50.57 s/epoch, 0.01 s/batch, ets 1972.20s
#
# Test set: Average loss: 0.5552, Accuracy: 9005/10000 (90%)
#
# Epoch: 21 Train Loss: 0.052034 Acc: 0.9814
# Elapsed 1117.01s, 50.77 s/epoch, 0.01 s/batch, ets 1929.38s
#
# Test set: Average loss: 0.5943, Accuracy: 8970/10000 (90%)
#
# Epoch: 22 Train Loss: 0.052807 Acc: 0.9810
# Elapsed 1171.41s, 50.93 s/epoch, 0.01 s/batch, ets 1884.45s
#
# Test set: Average loss: 0.5850, Accuracy: 9001/10000 (90%)
#
# Epoch: 23 Train Loss: 0.041889 Acc: 0.9846
# Elapsed 1225.53s, 51.06 s/epoch, 0.01 s/batch, ets 1838.29s
#
# Test set: Average loss: 0.6047, Accuracy: 8993/10000 (90%)
#
# Epoch: 24 Train Loss: 0.030742 Acc: 0.9886
# Elapsed 1280.44s, 51.22 s/epoch, 0.01 s/batch, ets 1792.61s
#
# Test set: Average loss: 0.6090, Accuracy: 9026/10000 (90%)
#
# Epoch: 25 Train Loss: 0.033341 Acc: 0.9886
# Elapsed 1336.23s, 51.39 s/epoch, 0.01 s/batch, ets 1747.38s
#
# Test set: Average loss: 0.6762, Accuracy: 8975/10000 (90%)
#
# Epoch: 26 Train Loss: 0.024366 Acc: 0.9913
# Elapsed 1390.96s, 51.52 s/epoch, 0.01 s/batch, ets 1700.06s
#
# Test set: Average loss: 0.7198, Accuracy: 9014/10000 (90%)
#
# Epoch: 27 Train Loss: 0.019871 Acc: 0.9926
# Elapsed 1444.74s, 51.60 s/epoch, 0.01 s/batch, ets 1651.13s
#
# Test set: Average loss: 0.7799, Accuracy: 9040/10000 (90%)
#
# Epoch: 28 Train Loss: 0.022894 Acc: 0.9924
# Elapsed 1498.77s, 51.68 s/epoch, 0.01 s/batch, ets 1602.13s
#
# Test set: Average loss: 0.7375, Accuracy: 8995/10000 (90%)
#
# Epoch: 29 Train Loss: 0.019568 Acc: 0.9930
# Elapsed 1554.92s, 51.83 s/epoch, 0.01 s/batch, ets 1554.92s
#
# Test set: Average loss: 0.7451, Accuracy: 9079/10000 (91%)
#
# Epoch: 30 Train Loss: 0.014624 Acc: 0.9946
# Elapsed 1610.90s, 51.96 s/epoch, 0.01 s/batch, ets 1506.97s
#
# Test set: Average loss: 0.7981, Accuracy: 9047/10000 (90%)
#
# Epoch: 31 Train Loss: 0.013883 Acc: 0.9955
# Elapsed 1669.82s, 52.18 s/epoch, 0.01 s/batch, ets 1461.09s
#
# Test set: Average loss: 0.8502, Accuracy: 9044/10000 (90%)
#
# Epoch: 32 Train Loss: 0.020834 Acc: 0.9931
# Elapsed 1727.26s, 52.34 s/epoch, 0.01 s/batch, ets 1413.21s
#
# Test set: Average loss: 0.8028, Accuracy: 9065/10000 (91%)
#
# Epoch: 33 Train Loss: 0.012873 Acc: 0.9956
# Elapsed 1785.52s, 52.52 s/epoch, 0.01 s/batch, ets 1365.40s
#
# Test set: Average loss: 0.8194, Accuracy: 9058/10000 (91%)
#
# Epoch: 34 Train Loss: 0.016475 Acc: 0.9950
# Elapsed 1842.17s, 52.63 s/epoch, 0.01 s/batch, ets 1315.84s
#
# Test set: Average loss: 0.8310, Accuracy: 9078/10000 (91%)
#
# Epoch: 35 Train Loss: 0.012104 Acc: 0.9960
# Elapsed 1903.34s, 52.87 s/epoch, 0.01 s/batch, ets 1268.89s
#
# Test set: Average loss: 0.8111, Accuracy: 9035/10000 (90%)
#
# Epoch: 36 Train Loss: 0.011108 Acc: 0.9964
# Elapsed 1958.89s, 52.94 s/epoch, 0.01 s/batch, ets 1217.69s
#
# Test set: Average loss: 0.8758, Accuracy: 9096/10000 (91%)
#
# Epoch: 37 Train Loss: 0.003550 Acc: 0.9988
# Elapsed 2022.08s, 53.21 s/epoch, 0.01 s/batch, ets 1170.68s
#
# Test set: Average loss: 0.9310, Accuracy: 9077/10000 (91%)
#
# Epoch: 38 Train Loss: 0.000527 Acc: 0.9999
# Elapsed 2090.90s, 53.61 s/epoch, 0.01 s/batch, ets 1125.87s
#
# Test set: Average loss: 0.9732, Accuracy: 9101/10000 (91%)
#
# Epoch: 39 Train Loss: 0.000147 Acc: 1.0000
# Elapsed 2154.81s, 53.87 s/epoch, 0.01 s/batch, ets 1077.41s
#
# Test set: Average loss: 1.0013, Accuracy: 9105/10000 (91%)
#
# Epoch: 40 Train Loss: 0.000086 Acc: 1.0000
# Elapsed 2217.44s, 54.08 s/epoch, 0.01 s/batch, ets 1027.59s
#
# Test set: Average loss: 1.0204, Accuracy: 9109/10000 (91%)
#
# Epoch: 41 Train Loss: 0.000068 Acc: 1.0000
# Elapsed 2278.64s, 54.25 s/epoch, 0.01 s/batch, ets 976.56s
#
# Test set: Average loss: 1.0344, Accuracy: 9107/10000 (91%)
#
# Epoch: 42 Train Loss: 0.000057 Acc: 1.0000
# Elapsed 2339.06s, 54.40 s/epoch, 0.01 s/batch, ets 924.75s
#
# Test set: Average loss: 1.0461, Accuracy: 9108/10000 (91%)
#
# Epoch: 43 Train Loss: 0.000049 Acc: 1.0000
# Elapsed 2404.87s, 54.66 s/epoch, 0.01 s/batch, ets 874.50s
#
# Test set: Average loss: 1.0565, Accuracy: 9108/10000 (91%)
#
# Epoch: 44 Train Loss: 0.000043 Acc: 1.0000
# Elapsed 2468.20s, 54.85 s/epoch, 0.01 s/batch, ets 822.73s
#
# Test set: Average loss: 1.0656, Accuracy: 9109/10000 (91%)
#
# Epoch: 45 Train Loss: 0.000039 Acc: 1.0000
# Elapsed 2531.95s, 55.04 s/epoch, 0.01 s/batch, ets 770.59s
#
# Test set: Average loss: 1.0735, Accuracy: 9107/10000 (91%)
#
# Epoch: 46 Train Loss: 0.000035 Acc: 1.0000
# Elapsed 2595.47s, 55.22 s/epoch, 0.01 s/batch, ets 717.90s
#
# Test set: Average loss: 1.0804, Accuracy: 9109/10000 (91%)
#
# Epoch: 47 Train Loss: 0.000032 Acc: 1.0000
# Elapsed 2661.52s, 55.45 s/epoch, 0.01 s/batch, ets 665.38s
#
# Test set: Average loss: 1.0871, Accuracy: 9112/10000 (91%)
#
# Epoch: 48 Train Loss: 0.000030 Acc: 1.0000
# Elapsed 2727.86s, 55.67 s/epoch, 0.01 s/batch, ets 612.38s
#
# Test set: Average loss: 1.0931, Accuracy: 9114/10000 (91%)
#
# Epoch: 49 Train Loss: 0.000028 Acc: 1.0000
# Elapsed 2795.10s, 55.90 s/epoch, 0.01 s/batch, ets 559.02s
#
# Test set: Average loss: 1.0985, Accuracy: 9112/10000 (91%)
#
# Epoch: 50 Train Loss: 0.000026 Acc: 1.0000
# Elapsed 2858.50s, 56.05 s/epoch, 0.01 s/batch, ets 504.44s
#
# Test set: Average loss: 1.1036, Accuracy: 9113/10000 (91%)
#
# Epoch: 51 Train Loss: 0.000024 Acc: 1.0000
# Elapsed 2926.53s, 56.28 s/epoch, 0.02 s/batch, ets 450.24s
#
# Test set: Average loss: 1.1084, Accuracy: 9114/10000 (91%)
#
# Epoch: 52 Train Loss: 0.000023 Acc: 1.0000
# Elapsed 2994.19s, 56.49 s/epoch, 0.02 s/batch, ets 395.46s
#
# Test set: Average loss: 1.1127, Accuracy: 9113/10000 (91%)
#
# Epoch: 53 Train Loss: 0.000022 Acc: 1.0000
# Elapsed 3059.95s, 56.67 s/epoch, 0.02 s/batch, ets 339.99s
#
# Test set: Average loss: 1.1167, Accuracy: 9114/10000 (91%)
#
# Epoch: 54 Train Loss: 0.000021 Acc: 1.0000
# Elapsed 3121.40s, 56.75 s/epoch, 0.02 s/batch, ets 283.76s
#
# Test set: Average loss: 1.1206, Accuracy: 9113/10000 (91%)
#
# Epoch: 55 Train Loss: 0.000020 Acc: 1.0000
# Elapsed 3182.96s, 56.84 s/epoch, 0.02 s/batch, ets 227.35s
#
# Test set: Average loss: 1.1243, Accuracy: 9113/10000 (91%)
#
# Epoch: 56 Train Loss: 0.000019 Acc: 1.0000
# Elapsed 3243.31s, 56.90 s/epoch, 0.02 s/batch, ets 170.70s
#
# Test set: Average loss: 1.1278, Accuracy: 9113/10000 (91%)
#
# Epoch: 57 Train Loss: 0.000018 Acc: 1.0000
# Elapsed 3305.32s, 56.99 s/epoch, 0.02 s/batch, ets 113.98s
#
# Test set: Average loss: 1.1310, Accuracy: 9112/10000 (91%)
#
# Epoch: 58 Train Loss: 0.000017 Acc: 1.0000
# Elapsed 3364.40s, 57.02 s/epoch, 0.02 s/batch, ets 57.02s
#
# Test set: Average loss: 1.1342, Accuracy: 9113/10000 (91%)
#
# Epoch: 59 Train Loss: 0.000017 Acc: 1.0000
# Elapsed 3422.49s, 57.04 s/epoch, 0.02 s/batch, ets 0.00s
#
# Test set: Average loss: 1.1372, Accuracy: 9114/10000 (91%)
#
# Total time: 3428.38, Best Loss: 0.293

# %%
plot_loss_accuracy(train_loss=[train_loss_exp2], 
                   val_loss=[val_loss_exp2], 
                   train_acc=[train_acc_exp2], 
                   val_acc=[val_acc_exp2], 
                   labels=['No Reg'], 
                   colors=['orange'], 
                   model_sizes=['M'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# Here, you can see that the network has reached a training accuracy of `1` and a training loss of almost `0`. This indicates the network has the required capacity. But do note that the validation loss and accuracy are nowhere close to the training percentages. This means the model is trying to memorize the training data. Rectify this, using the regularization techniques you have learnt so far.

# %% [markdown]
# ## <font style="color:green">3.2. Experiment 3: With Batch-Norm [M]</font><a name="M-with_BN"></a>
#
# Batch norm is familiar. Now, see if it can reduce overfitting. Add batch normalization to the network and train it.

# %%
model = MediumModel(batch_norm=True)
print(model)

optimizer, scheduler = get_optimizer_and_scheduler(model)

model, train_loss_exp3, train_acc_exp3, val_loss_exp3, val_acc_exp3 = main(model, 
                                                                           optimizer, 
                                                                           scheduler)
# Out:
# MediumModel(
#   (_body): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Dropout(p=0.0, inplace=False)
#   )
#   (_head): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=512, out_features=128, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# Epoch: 0 Train Loss: 0.463158 Acc: 0.8291
# Elapsed 47.03s, 47.03 s/epoch, 0.01 s/batch, ets 2774.81s
#
# Test set: Average loss: 0.3274, Accuracy: 8805/10000 (88%)
#
# Epoch: 1 Train Loss: 0.295266 Acc: 0.8919
# Elapsed 100.29s, 50.15 s/epoch, 0.01 s/batch, ets 2908.48s
#
# Test set: Average loss: 0.3253, Accuracy: 8778/10000 (88%)
#
# Epoch: 2 Train Loss: 0.248302 Acc: 0.9072
# Elapsed 153.26s, 51.09 s/epoch, 0.01 s/batch, ets 2911.99s
#
# Test set: Average loss: 0.2615, Accuracy: 9067/10000 (91%)
#
# Epoch: 3 Train Loss: 0.216543 Acc: 0.9201
# Elapsed 206.55s, 51.64 s/epoch, 0.01 s/batch, ets 2891.75s
#
# Test set: Average loss: 0.2522, Accuracy: 9077/10000 (91%)
#
# Epoch: 4 Train Loss: 0.190451 Acc: 0.9278
# Elapsed 261.04s, 52.21 s/epoch, 0.01 s/batch, ets 2871.49s
#
# Test set: Average loss: 0.2751, Accuracy: 9058/10000 (91%)
#
# Epoch: 5 Train Loss: 0.168034 Acc: 0.9366
# Elapsed 316.56s, 52.76 s/epoch, 0.01 s/batch, ets 2849.07s
#
# Test set: Average loss: 0.2453, Accuracy: 9132/10000 (91%)
#
# Epoch: 6 Train Loss: 0.149019 Acc: 0.9442
# Elapsed 371.90s, 53.13 s/epoch, 0.01 s/batch, ets 2815.80s
#
# Test set: Average loss: 0.3030, Accuracy: 8986/10000 (90%)
#
# Epoch: 7 Train Loss: 0.131309 Acc: 0.9493
# Elapsed 427.93s, 53.49 s/epoch, 0.01 s/batch, ets 2781.53s
#
# Test set: Average loss: 0.2532, Accuracy: 9191/10000 (92%)
#
# Epoch: 8 Train Loss: 0.114301 Acc: 0.9561
# Elapsed 483.69s, 53.74 s/epoch, 0.01 s/batch, ets 2740.90s
#
# Test set: Average loss: 0.2708, Accuracy: 9177/10000 (92%)
#
# Epoch: 9 Train Loss: 0.102368 Acc: 0.9607
# Elapsed 539.45s, 53.95 s/epoch, 0.01 s/batch, ets 2697.27s
#
# Test set: Average loss: 0.2950, Accuracy: 9125/10000 (91%)
#
# Epoch: 10 Train Loss: 0.088556 Acc: 0.9656
# Elapsed 594.75s, 54.07 s/epoch, 0.01 s/batch, ets 2649.35s
#
# Test set: Average loss: 0.3217, Accuracy: 9106/10000 (91%)
#
# Epoch: 11 Train Loss: 0.077225 Acc: 0.9706
# Elapsed 682.29s, 56.86 s/epoch, 0.02 s/batch, ets 2729.17s
#
# Test set: Average loss: 0.3059, Accuracy: 9206/10000 (92%)
#
# Epoch: 12 Train Loss: 0.067783 Acc: 0.9740
# Elapsed 738.53s, 56.81 s/epoch, 0.02 s/batch, ets 2670.07s
#
# Test set: Average loss: 0.3316, Accuracy: 9171/10000 (92%)
#
# Epoch: 13 Train Loss: 0.060238 Acc: 0.9766
# Elapsed 793.28s, 56.66 s/epoch, 0.02 s/batch, ets 2606.50s
#
# Test set: Average loss: 0.3460, Accuracy: 9173/10000 (92%)
#
# Epoch: 14 Train Loss: 0.051574 Acc: 0.9799
# Elapsed 848.58s, 56.57 s/epoch, 0.02 s/batch, ets 2545.75s
#
# Test set: Average loss: 0.3534, Accuracy: 9181/10000 (92%)
#
# Epoch: 15 Train Loss: 0.042845 Acc: 0.9829
# Elapsed 903.75s, 56.48 s/epoch, 0.02 s/batch, ets 2485.31s
#
# Test set: Average loss: 0.4002, Accuracy: 9161/10000 (92%)
#
# Epoch: 16 Train Loss: 0.042459 Acc: 0.9839
# Elapsed 959.99s, 56.47 s/epoch, 0.02 s/batch, ets 2428.22s
#
# Test set: Average loss: 0.4041, Accuracy: 9167/10000 (92%)
#
# Epoch: 17 Train Loss: 0.035977 Acc: 0.9863
# Elapsed 1016.05s, 56.45 s/epoch, 0.02 s/batch, ets 2370.78s
#
# Test set: Average loss: 0.4026, Accuracy: 9154/10000 (92%)
#
# Epoch: 18 Train Loss: 0.029813 Acc: 0.9889
# Elapsed 1072.78s, 56.46 s/epoch, 0.02 s/batch, ets 2314.94s
#
# Test set: Average loss: 0.4288, Accuracy: 9210/10000 (92%)
#
# Epoch: 19 Train Loss: 0.028340 Acc: 0.9897
# Elapsed 1125.95s, 56.30 s/epoch, 0.02 s/batch, ets 2251.90s
#
# Test set: Average loss: 0.4340, Accuracy: 9166/10000 (92%)
#
# Epoch: 20 Train Loss: 0.022287 Acc: 0.9919
# Elapsed 1179.10s, 56.15 s/epoch, 0.01 s/batch, ets 2189.75s
#
# Test set: Average loss: 0.4877, Accuracy: 9163/10000 (92%)
#
# Epoch: 21 Train Loss: 0.019533 Acc: 0.9925
# Elapsed 1230.88s, 55.95 s/epoch, 0.01 s/batch, ets 2126.06s
#
# Test set: Average loss: 0.4736, Accuracy: 9189/10000 (92%)
#
# Epoch: 22 Train Loss: 0.016511 Acc: 0.9938
# Elapsed 1288.08s, 56.00 s/epoch, 0.01 s/batch, ets 2072.14s
#
# Test set: Average loss: 0.4738, Accuracy: 9208/10000 (92%)
#
# Epoch: 23 Train Loss: 0.012728 Acc: 0.9955
# Elapsed 1341.69s, 55.90 s/epoch, 0.01 s/batch, ets 2012.54s
#
# Test set: Average loss: 0.5401, Accuracy: 9182/10000 (92%)
#
# Epoch: 24 Train Loss: 0.011350 Acc: 0.9957
# Elapsed 1397.05s, 55.88 s/epoch, 0.01 s/batch, ets 1955.87s
#
# Test set: Average loss: 0.5399, Accuracy: 9169/10000 (92%)
#
# Epoch: 25 Train Loss: 0.009116 Acc: 0.9964
# Elapsed 1450.18s, 55.78 s/epoch, 0.01 s/batch, ets 1896.39s
#
# Test set: Average loss: 0.5382, Accuracy: 9201/10000 (92%)
#
# Epoch: 26 Train Loss: 0.009206 Acc: 0.9969
# Elapsed 1506.47s, 55.80 s/epoch, 0.01 s/batch, ets 1841.25s
#
# Test set: Average loss: 0.5850, Accuracy: 9189/10000 (92%)
#
# Epoch: 27 Train Loss: 0.008922 Acc: 0.9969
# Elapsed 1558.98s, 55.68 s/epoch, 0.01 s/batch, ets 1781.69s
#
# Test set: Average loss: 0.5518, Accuracy: 9201/10000 (92%)
#
# Epoch: 28 Train Loss: 0.005038 Acc: 0.9983
# Elapsed 1613.87s, 55.65 s/epoch, 0.01 s/batch, ets 1725.17s
#
# Test set: Average loss: 0.5954, Accuracy: 9218/10000 (92%)
#
# Epoch: 29 Train Loss: 0.005489 Acc: 0.9983
# Elapsed 1677.12s, 55.90 s/epoch, 0.01 s/batch, ets 1677.12s
#
# Test set: Average loss: 0.5998, Accuracy: 9211/10000 (92%)
#
# Epoch: 30 Train Loss: 0.005009 Acc: 0.9985
# Elapsed 1742.21s, 56.20 s/epoch, 0.01 s/batch, ets 1629.81s
#
# Test set: Average loss: 0.6336, Accuracy: 9228/10000 (92%)
#
# Epoch: 31 Train Loss: 0.004950 Acc: 0.9983
# Elapsed 1807.51s, 56.48 s/epoch, 0.02 s/batch, ets 1581.57s
#
# Test set: Average loss: 0.6310, Accuracy: 9195/10000 (92%)
#
# Epoch: 32 Train Loss: 0.005621 Acc: 0.9980
# Elapsed 1859.50s, 56.35 s/epoch, 0.02 s/batch, ets 1521.41s
#
# Test set: Average loss: 0.6241, Accuracy: 9212/10000 (92%)
#
# Epoch: 33 Train Loss: 0.002966 Acc: 0.9992
# Elapsed 1912.19s, 56.24 s/epoch, 0.01 s/batch, ets 1462.26s
#
# Test set: Average loss: 0.6503, Accuracy: 9230/10000 (92%)
#
# Epoch: 34 Train Loss: 0.001762 Acc: 0.9996
# Elapsed 1964.66s, 56.13 s/epoch, 0.01 s/batch, ets 1403.33s
#
# Test set: Average loss: 0.6647, Accuracy: 9233/10000 (92%)
#
# Epoch: 35 Train Loss: 0.002729 Acc: 0.9992
# Elapsed 2016.45s, 56.01 s/epoch, 0.01 s/batch, ets 1344.30s
#
# Test set: Average loss: 0.6709, Accuracy: 9198/10000 (92%)
#
# Epoch: 36 Train Loss: 0.001432 Acc: 0.9997
# Elapsed 2069.45s, 55.93 s/epoch, 0.01 s/batch, ets 1286.42s
#
# Test set: Average loss: 0.6541, Accuracy: 9236/10000 (92%)
#
# Epoch: 37 Train Loss: 0.001299 Acc: 0.9997
# Elapsed 2123.30s, 55.88 s/epoch, 0.01 s/batch, ets 1229.28s
#
# Test set: Average loss: 0.6768, Accuracy: 9234/10000 (92%)
#
# Epoch: 38 Train Loss: 0.000833 Acc: 0.9999
# Elapsed 2176.18s, 55.80 s/epoch, 0.01 s/batch, ets 1171.79s
#
# Test set: Average loss: 0.7011, Accuracy: 9222/10000 (92%)
#
# Epoch: 39 Train Loss: 0.000785 Acc: 0.9998
# Elapsed 2229.13s, 55.73 s/epoch, 0.01 s/batch, ets 1114.57s
#
# Test set: Average loss: 0.7014, Accuracy: 9249/10000 (92%)
#
# Epoch: 40 Train Loss: 0.000414 Acc: 0.9999
# Elapsed 2282.70s, 55.68 s/epoch, 0.01 s/batch, ets 1057.84s
#
# Test set: Average loss: 0.7061, Accuracy: 9233/10000 (92%)
#
# Epoch: 41 Train Loss: 0.000307 Acc: 1.0000
# Elapsed 2336.12s, 55.62 s/epoch, 0.01 s/batch, ets 1001.20s
#
# Test set: Average loss: 0.7145, Accuracy: 9236/10000 (92%)
#
# Epoch: 42 Train Loss: 0.000208 Acc: 1.0000
# Elapsed 2389.16s, 55.56 s/epoch, 0.01 s/batch, ets 944.55s
#
# Test set: Average loss: 0.7138, Accuracy: 9245/10000 (92%)
#
# Epoch: 43 Train Loss: 0.000543 Acc: 0.9999
# Elapsed 2447.22s, 55.62 s/epoch, 0.01 s/batch, ets 889.90s
#
# Test set: Average loss: 0.7236, Accuracy: 9249/10000 (92%)
#
# Epoch: 44 Train Loss: 0.000531 Acc: 0.9999
# Elapsed 2503.47s, 55.63 s/epoch, 0.01 s/batch, ets 834.49s
#
# Test set: Average loss: 0.7184, Accuracy: 9245/10000 (92%)
#
# Epoch: 45 Train Loss: 0.000228 Acc: 1.0000
# Elapsed 2559.40s, 55.64 s/epoch, 0.01 s/batch, ets 778.95s
#
# Test set: Average loss: 0.7249, Accuracy: 9237/10000 (92%)
#
# Epoch: 46 Train Loss: 0.000152 Acc: 1.0000
# Elapsed 2615.21s, 55.64 s/epoch, 0.01 s/batch, ets 723.36s
#
# Test set: Average loss: 0.7389, Accuracy: 9247/10000 (92%)
#
# Epoch: 47 Train Loss: 0.000143 Acc: 1.0000
# Elapsed 2670.86s, 55.64 s/epoch, 0.01 s/batch, ets 667.71s
#
# Test set: Average loss: 0.7418, Accuracy: 9246/10000 (92%)
#
# Epoch: 48 Train Loss: 0.000286 Acc: 1.0000
# Elapsed 2726.28s, 55.64 s/epoch, 0.01 s/batch, ets 612.02s
#
# Test set: Average loss: 0.7470, Accuracy: 9249/10000 (92%)
#
# Epoch: 49 Train Loss: 0.000098 Acc: 1.0000
# Elapsed 2783.41s, 55.67 s/epoch, 0.01 s/batch, ets 556.68s
#
# Test set: Average loss: 0.7353, Accuracy: 9252/10000 (93%)
#
# Epoch: 50 Train Loss: 0.000077 Acc: 1.0000
# Elapsed 2839.47s, 55.68 s/epoch, 0.01 s/batch, ets 501.08s
#
# Test set: Average loss: 0.7480, Accuracy: 9251/10000 (93%)
#
# Epoch: 51 Train Loss: 0.000091 Acc: 1.0000
# Elapsed 2893.61s, 55.65 s/epoch, 0.01 s/batch, ets 445.17s
#
# Test set: Average loss: 0.7572, Accuracy: 9247/10000 (92%)
#
# Epoch: 52 Train Loss: 0.000083 Acc: 1.0000
# Elapsed 2947.06s, 55.60 s/epoch, 0.01 s/batch, ets 389.23s
#
# Test set: Average loss: 0.7716, Accuracy: 9248/10000 (92%)
#
# Epoch: 53 Train Loss: 0.000065 Acc: 1.0000
# Elapsed 3002.78s, 55.61 s/epoch, 0.01 s/batch, ets 333.64s
#
# Test set: Average loss: 0.7592, Accuracy: 9238/10000 (92%)
#
# Epoch: 54 Train Loss: 0.000080 Acc: 1.0000
# Elapsed 3057.03s, 55.58 s/epoch, 0.01 s/batch, ets 277.91s
#
# Test set: Average loss: 0.7703, Accuracy: 9243/10000 (92%)
#
# Epoch: 55 Train Loss: 0.000085 Acc: 1.0000
# Elapsed 3110.32s, 55.54 s/epoch, 0.01 s/batch, ets 222.17s
#
# Test set: Average loss: 0.7809, Accuracy: 9240/10000 (92%)
#
# Epoch: 56 Train Loss: 0.000078 Acc: 1.0000
# Elapsed 3164.95s, 55.53 s/epoch, 0.01 s/batch, ets 166.58s
#
# Test set: Average loss: 0.7639, Accuracy: 9247/10000 (92%)
#
# Epoch: 57 Train Loss: 0.000060 Acc: 1.0000
# Elapsed 3219.37s, 55.51 s/epoch, 0.01 s/batch, ets 111.01s
#
# Test set: Average loss: 0.7694, Accuracy: 9229/10000 (92%)
#
# Epoch: 58 Train Loss: 0.000056 Acc: 1.0000
# Elapsed 3278.54s, 55.57 s/epoch, 0.01 s/batch, ets 55.57s
#
# Test set: Average loss: 0.7806, Accuracy: 9241/10000 (92%)
#
# Epoch: 59 Train Loss: 0.000061 Acc: 1.0000
# Elapsed 3334.06s, 55.57 s/epoch, 0.01 s/batch, ets 0.00s
#
# Test set: Average loss: 0.7852, Accuracy: 9247/10000 (92%)
#
# Total time: 3340.70, Best Loss: 0.245

# %%
plot_loss_accuracy(train_loss=[train_loss_exp3], 
                   val_loss=[val_loss_exp3], 
                   train_acc=[train_acc_exp3], 
                   val_acc=[val_acc_exp3], 
                   labels=['BN'], 
                   colors=['green'], 
                   model_sizes=['M'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# ## <font style="color:green">3.3 Experiment 4: With Dropout [M]</font><a name="M-with_Drop"></a>
#
# Add Dropout Regularization. Add dropout layers with probability, `0.25`.

# %%
model = MediumModel(0.25)
print(model)

optimizer, scheduler = get_optimizer_and_scheduler(model)

model, train_loss_exp4, train_acc_exp4, val_loss_exp4, val_acc_exp4 = main(model, 
                                                                           optimizer, 
                                                                           scheduler)
# Out:
# MediumModel(
#   (_body): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Dropout(p=0.25, inplace=False)
#   )
#   (_head): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=512, out_features=128, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.25, inplace=False)
#     (6): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# Epoch: 0 Train Loss: 0.621820 Acc: 0.7725
# Elapsed 43.16s, 43.16 s/epoch, 0.01 s/batch, ets 2546.35s
#
# Test set: Average loss: 0.4343, Accuracy: 8393/10000 (84%)
#
# Epoch: 1 Train Loss: 0.429921 Acc: 0.8433
# Elapsed 94.09s, 47.04 s/epoch, 0.01 s/batch, ets 2728.47s
#
# Test set: Average loss: 0.3688, Accuracy: 8578/10000 (86%)
#
# Epoch: 2 Train Loss: 0.386289 Acc: 0.8578
# Elapsed 144.09s, 48.03 s/epoch, 0.01 s/batch, ets 2737.76s
#
# Test set: Average loss: 0.3687, Accuracy: 8642/10000 (86%)
#
# Epoch: 3 Train Loss: 0.355899 Acc: 0.8685
# Elapsed 194.58s, 48.64 s/epoch, 0.01 s/batch, ets 2724.10s
#
# Test set: Average loss: 0.3350, Accuracy: 8707/10000 (87%)
#
# Epoch: 4 Train Loss: 0.332937 Acc: 0.8763
# Elapsed 244.03s, 48.81 s/epoch, 0.01 s/batch, ets 2684.29s
#
# Test set: Average loss: 0.3294, Accuracy: 8805/10000 (88%)
#
# Epoch: 5 Train Loss: 0.319410 Acc: 0.8817
# Elapsed 294.47s, 49.08 s/epoch, 0.01 s/batch, ets 2650.19s
#
# Test set: Average loss: 0.3111, Accuracy: 8840/10000 (88%)
#
# Epoch: 6 Train Loss: 0.300637 Acc: 0.8877
# Elapsed 344.33s, 49.19 s/epoch, 0.01 s/batch, ets 2607.09s
#
# Test set: Average loss: 0.3339, Accuracy: 8770/10000 (88%)
#
# Epoch: 7 Train Loss: 0.288292 Acc: 0.8911
# Elapsed 395.54s, 49.44 s/epoch, 0.01 s/batch, ets 2571.02s
#
# Test set: Average loss: 0.3153, Accuracy: 8890/10000 (89%)
#
# Epoch: 8 Train Loss: 0.278746 Acc: 0.8954
# Elapsed 447.10s, 49.68 s/epoch, 0.01 s/batch, ets 2533.55s
#
# Test set: Average loss: 0.2939, Accuracy: 8947/10000 (89%)
#
# Epoch: 9 Train Loss: 0.261894 Acc: 0.9019
# Elapsed 497.27s, 49.73 s/epoch, 0.01 s/batch, ets 2486.36s
#
# Test set: Average loss: 0.3143, Accuracy: 8834/10000 (88%)
#
# Epoch: 10 Train Loss: 0.254568 Acc: 0.9060
# Elapsed 546.55s, 49.69 s/epoch, 0.01 s/batch, ets 2434.64s
#
# Test set: Average loss: 0.2975, Accuracy: 8977/10000 (90%)
#
# Epoch: 11 Train Loss: 0.244417 Acc: 0.9093
# Elapsed 596.73s, 49.73 s/epoch, 0.01 s/batch, ets 2386.90s
#
# Test set: Average loss: 0.2903, Accuracy: 8986/10000 (90%)
#
# Epoch: 12 Train Loss: 0.237026 Acc: 0.9115
# Elapsed 646.85s, 49.76 s/epoch, 0.01 s/batch, ets 2338.60s
#
# Test set: Average loss: 0.2778, Accuracy: 9034/10000 (90%)
#
# Epoch: 13 Train Loss: 0.225902 Acc: 0.9159
# Elapsed 699.25s, 49.95 s/epoch, 0.01 s/batch, ets 2297.52s
#
# Test set: Average loss: 0.2997, Accuracy: 8968/10000 (90%)
#
# Epoch: 14 Train Loss: 0.215428 Acc: 0.9190
# Elapsed 753.93s, 50.26 s/epoch, 0.01 s/batch, ets 2261.79s
#
# Test set: Average loss: 0.2976, Accuracy: 9064/10000 (91%)
#
# Epoch: 15 Train Loss: 0.210356 Acc: 0.9202
# Elapsed 804.22s, 50.26 s/epoch, 0.01 s/batch, ets 2211.59s
#
# Test set: Average loss: 0.2831, Accuracy: 9073/10000 (91%)
#
# Epoch: 16 Train Loss: 0.202004 Acc: 0.9246
# Elapsed 858.19s, 50.48 s/epoch, 0.01 s/batch, ets 2170.73s
#
# Test set: Average loss: 0.2899, Accuracy: 9028/10000 (90%)
#
# Epoch: 17 Train Loss: 0.193723 Acc: 0.9273
# Elapsed 911.96s, 50.66 s/epoch, 0.01 s/batch, ets 2127.91s
#
# Test set: Average loss: 0.2900, Accuracy: 9051/10000 (91%)
#
# Epoch: 18 Train Loss: 0.184619 Acc: 0.9305
# Elapsed 961.90s, 50.63 s/epoch, 0.01 s/batch, ets 2075.69s
#
# Test set: Average loss: 0.2862, Accuracy: 9049/10000 (90%)
#
# Epoch: 19 Train Loss: 0.179929 Acc: 0.9307
# Elapsed 1010.96s, 50.55 s/epoch, 0.01 s/batch, ets 2021.91s
#
# Test set: Average loss: 0.2924, Accuracy: 9058/10000 (91%)
#
# Epoch: 20 Train Loss: 0.179006 Acc: 0.9322
# Elapsed 1060.59s, 50.50 s/epoch, 0.01 s/batch, ets 1969.67s
#
# Test set: Average loss: 0.2889, Accuracy: 9066/10000 (91%)
#
# Epoch: 21 Train Loss: 0.169886 Acc: 0.9355
# Elapsed 1110.05s, 50.46 s/epoch, 0.01 s/batch, ets 1917.36s
#
# Test set: Average loss: 0.2868, Accuracy: 9043/10000 (90%)
#
# Epoch: 22 Train Loss: 0.163941 Acc: 0.9371
# Elapsed 1158.34s, 50.36 s/epoch, 0.01 s/batch, ets 1863.41s
#
# Test set: Average loss: 0.2900, Accuracy: 9073/10000 (91%)
#
# Epoch: 23 Train Loss: 0.164051 Acc: 0.9385
# Elapsed 1207.15s, 50.30 s/epoch, 0.01 s/batch, ets 1810.73s
#
# Test set: Average loss: 0.2892, Accuracy: 9081/10000 (91%)
#
# Epoch: 24 Train Loss: 0.153286 Acc: 0.9418
# Elapsed 1257.27s, 50.29 s/epoch, 0.01 s/batch, ets 1760.18s
#
# Test set: Average loss: 0.2955, Accuracy: 9095/10000 (91%)
#
# Epoch: 25 Train Loss: 0.150055 Acc: 0.9434
# Elapsed 1307.16s, 50.28 s/epoch, 0.01 s/batch, ets 1709.36s
#
# Test set: Average loss: 0.2855, Accuracy: 9091/10000 (91%)
#
# Epoch: 26 Train Loss: 0.144100 Acc: 0.9464
# Elapsed 1356.79s, 50.25 s/epoch, 0.01 s/batch, ets 1658.29s
#
# Test set: Average loss: 0.2869, Accuracy: 9117/10000 (91%)
#
# Epoch: 27 Train Loss: 0.142939 Acc: 0.9455
# Elapsed 1407.05s, 50.25 s/epoch, 0.01 s/batch, ets 1608.05s
#
# Test set: Average loss: 0.2923, Accuracy: 9098/10000 (91%)
#
# Epoch: 28 Train Loss: 0.138384 Acc: 0.9474
# Elapsed 1455.75s, 50.20 s/epoch, 0.01 s/batch, ets 1556.14s
#
# Test set: Average loss: 0.3104, Accuracy: 9066/10000 (91%)
#
# Epoch: 29 Train Loss: 0.134046 Acc: 0.9493
# Elapsed 1506.49s, 50.22 s/epoch, 0.01 s/batch, ets 1506.49s
#
# Test set: Average loss: 0.3076, Accuracy: 9098/10000 (91%)
#
# Epoch: 30 Train Loss: 0.127249 Acc: 0.9505
# Elapsed 1556.55s, 50.21 s/epoch, 0.01 s/batch, ets 1456.13s
#
# Test set: Average loss: 0.3068, Accuracy: 9063/10000 (91%)
#
# Epoch: 31 Train Loss: 0.125734 Acc: 0.9526
# Elapsed 1606.86s, 50.21 s/epoch, 0.01 s/batch, ets 1406.00s
#
# Test set: Average loss: 0.3064, Accuracy: 9086/10000 (91%)
#
# Epoch: 32 Train Loss: 0.121750 Acc: 0.9536
# Elapsed 1656.33s, 50.19 s/epoch, 0.01 s/batch, ets 1355.18s
#
# Test set: Average loss: 0.3063, Accuracy: 9082/10000 (91%)
#
# Epoch: 33 Train Loss: 0.116774 Acc: 0.9556
# Elapsed 1705.96s, 50.18 s/epoch, 0.01 s/batch, ets 1304.56s
#
# Test set: Average loss: 0.3094, Accuracy: 9106/10000 (91%)
#
# Epoch: 34 Train Loss: 0.114868 Acc: 0.9564
# Elapsed 1755.00s, 50.14 s/epoch, 0.01 s/batch, ets 1253.57s
#
# Test set: Average loss: 0.3113, Accuracy: 9081/10000 (91%)
#
# Epoch: 35 Train Loss: 0.111047 Acc: 0.9581
# Elapsed 1805.20s, 50.14 s/epoch, 0.01 s/batch, ets 1203.47s
#
# Test set: Average loss: 0.3234, Accuracy: 9093/10000 (91%)
#
# Epoch: 36 Train Loss: 0.108533 Acc: 0.9578
# Elapsed 1856.41s, 50.17 s/epoch, 0.01 s/batch, ets 1153.99s
#
# Test set: Average loss: 0.3110, Accuracy: 9109/10000 (91%)
#
# Epoch: 37 Train Loss: 0.105081 Acc: 0.9600
# Elapsed 1906.71s, 50.18 s/epoch, 0.01 s/batch, ets 1103.88s
#
# Test set: Average loss: 0.3207, Accuracy: 9098/10000 (91%)
#
# Epoch: 38 Train Loss: 0.102514 Acc: 0.9599
# Elapsed 1956.25s, 50.16 s/epoch, 0.01 s/batch, ets 1053.37s
#
# Test set: Average loss: 0.3290, Accuracy: 9128/10000 (91%)
#
# Epoch: 39 Train Loss: 0.101233 Acc: 0.9618
# Elapsed 2006.57s, 50.16 s/epoch, 0.01 s/batch, ets 1003.28s
#
# Test set: Average loss: 0.3155, Accuracy: 9111/10000 (91%)
#
# Epoch: 40 Train Loss: 0.097961 Acc: 0.9631
# Elapsed 2055.50s, 50.13 s/epoch, 0.01 s/batch, ets 952.55s
#
# Test set: Average loss: 0.3256, Accuracy: 9120/10000 (91%)
#
# Epoch: 41 Train Loss: 0.097010 Acc: 0.9639
# Elapsed 2106.44s, 50.15 s/epoch, 0.01 s/batch, ets 902.76s
#
# Test set: Average loss: 0.3285, Accuracy: 9133/10000 (91%)
#
# Epoch: 42 Train Loss: 0.091868 Acc: 0.9656
# Elapsed 2156.47s, 50.15 s/epoch, 0.01 s/batch, ets 852.56s
#
# Test set: Average loss: 0.3360, Accuracy: 9121/10000 (91%)
#
# Epoch: 43 Train Loss: 0.090501 Acc: 0.9660
# Elapsed 2206.30s, 50.14 s/epoch, 0.01 s/batch, ets 802.29s
#
# Test set: Average loss: 0.3467, Accuracy: 9119/10000 (91%)
#
# Epoch: 44 Train Loss: 0.089087 Acc: 0.9664
# Elapsed 2256.82s, 50.15 s/epoch, 0.01 s/batch, ets 752.27s
#
# Test set: Average loss: 0.3487, Accuracy: 9120/10000 (91%)
#
# Epoch: 45 Train Loss: 0.083658 Acc: 0.9685
# Elapsed 2308.04s, 50.17 s/epoch, 0.01 s/batch, ets 702.45s
#
# Test set: Average loss: 0.3463, Accuracy: 9091/10000 (91%)
#
# Epoch: 46 Train Loss: 0.081176 Acc: 0.9689
# Elapsed 2357.72s, 50.16 s/epoch, 0.01 s/batch, ets 652.13s
#
# Test set: Average loss: 0.3562, Accuracy: 9110/10000 (91%)
#
# Epoch: 47 Train Loss: 0.082661 Acc: 0.9684
# Elapsed 2407.84s, 50.16 s/epoch, 0.01 s/batch, ets 601.96s
#
# Test set: Average loss: 0.3561, Accuracy: 9096/10000 (91%)
#
# Epoch: 48 Train Loss: 0.081369 Acc: 0.9692
# Elapsed 2457.77s, 50.16 s/epoch, 0.01 s/batch, ets 551.74s
#
# Test set: Average loss: 0.3488, Accuracy: 9100/10000 (91%)
#
# Epoch: 49 Train Loss: 0.078177 Acc: 0.9709
# Elapsed 2508.82s, 50.18 s/epoch, 0.01 s/batch, ets 501.76s
#
# Test set: Average loss: 0.3629, Accuracy: 9104/10000 (91%)
#
# Epoch: 50 Train Loss: 0.078487 Acc: 0.9707
# Elapsed 2559.23s, 50.18 s/epoch, 0.01 s/batch, ets 451.63s
#
# Test set: Average loss: 0.3418, Accuracy: 9107/10000 (91%)
#
# Epoch: 51 Train Loss: 0.073863 Acc: 0.9727
# Elapsed 2609.64s, 50.19 s/epoch, 0.01 s/batch, ets 401.48s
#
# Test set: Average loss: 0.3568, Accuracy: 9140/10000 (91%)
#
# Epoch: 52 Train Loss: 0.074404 Acc: 0.9726
# Elapsed 2659.34s, 50.18 s/epoch, 0.01 s/batch, ets 351.23s
#
# Test set: Average loss: 0.3628, Accuracy: 9108/10000 (91%)
#
# Epoch: 53 Train Loss: 0.074738 Acc: 0.9716
# Elapsed 2710.27s, 50.19 s/epoch, 0.01 s/batch, ets 301.14s
#
# Test set: Average loss: 0.3709, Accuracy: 9102/10000 (91%)
#
# Epoch: 54 Train Loss: 0.071641 Acc: 0.9730
# Elapsed 2760.14s, 50.18 s/epoch, 0.01 s/batch, ets 250.92s
#
# Test set: Average loss: 0.3673, Accuracy: 9116/10000 (91%)
#
# Epoch: 55 Train Loss: 0.069922 Acc: 0.9738
# Elapsed 2810.31s, 50.18 s/epoch, 0.01 s/batch, ets 200.74s
#
# Test set: Average loss: 0.3676, Accuracy: 9108/10000 (91%)
#
# Epoch: 56 Train Loss: 0.065683 Acc: 0.9754
# Elapsed 2860.49s, 50.18 s/epoch, 0.01 s/batch, ets 150.55s
#
# Test set: Average loss: 0.3642, Accuracy: 9119/10000 (91%)
#
# Epoch: 57 Train Loss: 0.065663 Acc: 0.9751
# Elapsed 2910.43s, 50.18 s/epoch, 0.01 s/batch, ets 100.36s
#
# Test set: Average loss: 0.3789, Accuracy: 9094/10000 (91%)
#
# Epoch: 58 Train Loss: 0.064481 Acc: 0.9755
# Elapsed 2960.98s, 50.19 s/epoch, 0.01 s/batch, ets 50.19s
#
# Test set: Average loss: 0.3789, Accuracy: 9100/10000 (91%)
#
# Epoch: 59 Train Loss: 0.064729 Acc: 0.9768
# Elapsed 3010.51s, 50.18 s/epoch, 0.01 s/batch, ets 0.00s
#
# Test set: Average loss: 0.3741, Accuracy: 9097/10000 (91%)
#
# Total time: 3016.29, Best Loss: 0.278

# %%
plot_loss_accuracy(train_loss=[train_loss_exp4], 
                   val_loss=[val_loss_exp4], 
                   train_acc=[train_acc_exp4], 
                   val_acc=[val_acc_exp4], 
                   labels=['Drop'], 
                   colors=['red'], 
                   model_sizes=['M'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# It’s clear that the addition of Dropout  layer effects the validation curves substantially more than Batch Norm. Think of it as training the network on missing data. So, it learns more robust features.

# %% [markdown]
# ## <font style="color:green">3.4. Experiment 5: With Batch-Norm and Dropout [M]</font><a name="M-with_B_and_Drop"></a>
#
# Apply both Batch Norm and Dropout. See the effect of this double dose.

# %%
model = MediumModel(0.25, batch_norm=True)
print(model)

optimizer, scheduler = get_optimizer_and_scheduler(model)

model, train_loss_exp5, train_acc_exp5, val_loss_exp5, val_acc_exp5 = main(model, 
                                                                           optimizer, 
                                                                           scheduler)
# Out:
# MediumModel(
#   (_body): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Dropout(p=0.25, inplace=False)
#   )
#   (_head): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=512, out_features=128, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.25, inplace=False)
#     (6): Linear(in_features=128, out_features=10, bias=True)
#   )
# )
# Epoch: 0 Train Loss: 0.555811 Acc: 0.7984
# Elapsed 51.50s, 51.50 s/epoch, 0.01 s/batch, ets 3038.30s
#
# Test set: Average loss: 0.3756, Accuracy: 8577/10000 (86%)
#
# Epoch: 1 Train Loss: 0.372635 Acc: 0.8648
# Elapsed 111.56s, 55.78 s/epoch, 0.01 s/batch, ets 3235.29s
#
# Test set: Average loss: 0.3254, Accuracy: 8789/10000 (88%)
#
# Epoch: 2 Train Loss: 0.322901 Acc: 0.8838
# Elapsed 167.63s, 55.88 s/epoch, 0.01 s/batch, ets 3184.89s
#
# Test set: Average loss: 0.3182, Accuracy: 8769/10000 (88%)
#
# Epoch: 3 Train Loss: 0.293218 Acc: 0.8925
# Elapsed 228.60s, 57.15 s/epoch, 0.02 s/batch, ets 3200.39s
#
# Test set: Average loss: 0.2667, Accuracy: 9032/10000 (90%)
#
# Epoch: 4 Train Loss: 0.270153 Acc: 0.9006
# Elapsed 286.74s, 57.35 s/epoch, 0.02 s/batch, ets 3154.14s
#
# Test set: Average loss: 0.2627, Accuracy: 9028/10000 (90%)
#
# Epoch: 5 Train Loss: 0.255694 Acc: 0.9064
# Elapsed 340.19s, 56.70 s/epoch, 0.02 s/batch, ets 3061.71s
#
# Test set: Average loss: 0.2685, Accuracy: 9029/10000 (90%)
#
# Epoch: 6 Train Loss: 0.242126 Acc: 0.9103
# Elapsed 393.39s, 56.20 s/epoch, 0.01 s/batch, ets 2978.56s
#
# Test set: Average loss: 0.2385, Accuracy: 9098/10000 (91%)
#
# Epoch: 7 Train Loss: 0.228680 Acc: 0.9154
# Elapsed 446.25s, 55.78 s/epoch, 0.01 s/batch, ets 2900.60s
#
# Test set: Average loss: 0.2381, Accuracy: 9116/10000 (91%)
#
# Epoch: 8 Train Loss: 0.215191 Acc: 0.9189
# Elapsed 500.23s, 55.58 s/epoch, 0.01 s/batch, ets 2834.66s
#
# Test set: Average loss: 0.2483, Accuracy: 9138/10000 (91%)
#
# Epoch: 9 Train Loss: 0.208020 Acc: 0.9233
# Elapsed 553.17s, 55.32 s/epoch, 0.01 s/batch, ets 2765.87s
#
# Test set: Average loss: 0.2376, Accuracy: 9141/10000 (91%)
#
# Epoch: 10 Train Loss: 0.195621 Acc: 0.9267
# Elapsed 606.10s, 55.10 s/epoch, 0.01 s/batch, ets 2699.89s
#
# Test set: Average loss: 0.2344, Accuracy: 9161/10000 (92%)
#
# Epoch: 11 Train Loss: 0.187763 Acc: 0.9302
# Elapsed 659.07s, 54.92 s/epoch, 0.01 s/batch, ets 2636.29s
#
# Test set: Average loss: 0.2254, Accuracy: 9188/10000 (92%)
#
# Epoch: 12 Train Loss: 0.179412 Acc: 0.9328
# Elapsed 712.14s, 54.78 s/epoch, 0.01 s/batch, ets 2574.65s
#
# Test set: Average loss: 0.2336, Accuracy: 9202/10000 (92%)
#
# Epoch: 13 Train Loss: 0.171028 Acc: 0.9359
# Elapsed 765.09s, 54.65 s/epoch, 0.01 s/batch, ets 2513.88s
#
# Test set: Average loss: 0.2288, Accuracy: 9169/10000 (92%)
#
# Epoch: 14 Train Loss: 0.164330 Acc: 0.9373
# Elapsed 817.75s, 54.52 s/epoch, 0.01 s/batch, ets 2453.25s
#
# Test set: Average loss: 0.2311, Accuracy: 9218/10000 (92%)
#
# Epoch: 15 Train Loss: 0.157828 Acc: 0.9410
# Elapsed 870.31s, 54.39 s/epoch, 0.01 s/batch, ets 2393.34s
#
# Test set: Average loss: 0.2377, Accuracy: 9200/10000 (92%)
#
# Epoch: 16 Train Loss: 0.154375 Acc: 0.9413
# Elapsed 922.91s, 54.29 s/epoch, 0.01 s/batch, ets 2334.41s
#
# Test set: Average loss: 0.2283, Accuracy: 9229/10000 (92%)
#
# Epoch: 17 Train Loss: 0.146914 Acc: 0.9452
# Elapsed 975.74s, 54.21 s/epoch, 0.01 s/batch, ets 2276.73s
#
# Test set: Average loss: 0.2305, Accuracy: 9224/10000 (92%)
#
# Epoch: 18 Train Loss: 0.141462 Acc: 0.9464
# Elapsed 1028.84s, 54.15 s/epoch, 0.01 s/batch, ets 2220.13s
#
# Test set: Average loss: 0.2377, Accuracy: 9214/10000 (92%)
#
# Epoch: 19 Train Loss: 0.138738 Acc: 0.9473
# Elapsed 1082.45s, 54.12 s/epoch, 0.01 s/batch, ets 2164.90s
#
# Test set: Average loss: 0.2386, Accuracy: 9188/10000 (92%)
#
# Epoch: 20 Train Loss: 0.134567 Acc: 0.9494
# Elapsed 1134.98s, 54.05 s/epoch, 0.01 s/batch, ets 2107.81s
#
# Test set: Average loss: 0.2396, Accuracy: 9217/10000 (92%)
#
# Epoch: 21 Train Loss: 0.128938 Acc: 0.9514
# Elapsed 1188.42s, 54.02 s/epoch, 0.01 s/batch, ets 2052.72s
#
# Test set: Average loss: 0.2423, Accuracy: 9224/10000 (92%)
#
# Epoch: 22 Train Loss: 0.124807 Acc: 0.9529
# Elapsed 1239.53s, 53.89 s/epoch, 0.01 s/batch, ets 1994.02s
#
# Test set: Average loss: 0.2434, Accuracy: 9237/10000 (92%)
#
# Epoch: 23 Train Loss: 0.120741 Acc: 0.9550
# Elapsed 1290.38s, 53.77 s/epoch, 0.01 s/batch, ets 1935.57s
#
# Test set: Average loss: 0.2384, Accuracy: 9238/10000 (92%)
#
# Epoch: 24 Train Loss: 0.118351 Acc: 0.9559
# Elapsed 1341.08s, 53.64 s/epoch, 0.01 s/batch, ets 1877.51s
#
# Test set: Average loss: 0.2388, Accuracy: 9279/10000 (93%)
#
# Epoch: 25 Train Loss: 0.113484 Acc: 0.9571
# Elapsed 1392.25s, 53.55 s/epoch, 0.01 s/batch, ets 1820.64s
#
# Test set: Average loss: 0.2440, Accuracy: 9254/10000 (93%)
#
# Epoch: 26 Train Loss: 0.112381 Acc: 0.9576
# Elapsed 1443.65s, 53.47 s/epoch, 0.01 s/batch, ets 1764.47s
#
# Test set: Average loss: 0.2394, Accuracy: 9259/10000 (93%)
#
# Epoch: 27 Train Loss: 0.105163 Acc: 0.9602
# Elapsed 1494.69s, 53.38 s/epoch, 0.01 s/batch, ets 1708.22s
#
# Test set: Average loss: 0.2477, Accuracy: 9248/10000 (92%)
#
# Epoch: 28 Train Loss: 0.102257 Acc: 0.9621
# Elapsed 1545.13s, 53.28 s/epoch, 0.01 s/batch, ets 1651.69s
#
# Test set: Average loss: 0.2426, Accuracy: 9244/10000 (92%)
#
# Epoch: 29 Train Loss: 0.100723 Acc: 0.9617
# Elapsed 1596.43s, 53.21 s/epoch, 0.01 s/batch, ets 1596.43s
#
# Test set: Average loss: 0.2526, Accuracy: 9257/10000 (93%)
#
# Epoch: 30 Train Loss: 0.097307 Acc: 0.9636
# Elapsed 1647.52s, 53.15 s/epoch, 0.01 s/batch, ets 1541.22s
#
# Test set: Average loss: 0.2479, Accuracy: 9276/10000 (93%)
#
# Epoch: 31 Train Loss: 0.094638 Acc: 0.9635
# Elapsed 1698.39s, 53.07 s/epoch, 0.01 s/batch, ets 1486.09s
#
# Test set: Average loss: 0.2493, Accuracy: 9285/10000 (93%)
#
# Epoch: 32 Train Loss: 0.090884 Acc: 0.9655
# Elapsed 1749.57s, 53.02 s/epoch, 0.01 s/batch, ets 1431.47s
#
# Test set: Average loss: 0.2623, Accuracy: 9267/10000 (93%)
#
# Epoch: 33 Train Loss: 0.092442 Acc: 0.9647
# Elapsed 1800.11s, 52.94 s/epoch, 0.01 s/batch, ets 1376.55s
#
# Test set: Average loss: 0.2641, Accuracy: 9253/10000 (93%)
#
# Epoch: 34 Train Loss: 0.085540 Acc: 0.9669
# Elapsed 1851.23s, 52.89 s/epoch, 0.01 s/batch, ets 1322.31s
#
# Test set: Average loss: 0.2618, Accuracy: 9268/10000 (93%)
#
# Epoch: 35 Train Loss: 0.085519 Acc: 0.9672
# Elapsed 1902.18s, 52.84 s/epoch, 0.01 s/batch, ets 1268.12s
#
# Test set: Average loss: 0.2623, Accuracy: 9253/10000 (93%)
#
# Epoch: 36 Train Loss: 0.083990 Acc: 0.9684
# Elapsed 1952.78s, 52.78 s/epoch, 0.01 s/batch, ets 1213.89s
#
# Test set: Average loss: 0.2651, Accuracy: 9261/10000 (93%)
#
# Epoch: 37 Train Loss: 0.079009 Acc: 0.9705
# Elapsed 2003.95s, 52.74 s/epoch, 0.01 s/batch, ets 1160.18s
#
# Test set: Average loss: 0.2701, Accuracy: 9255/10000 (93%)
#
# Epoch: 38 Train Loss: 0.077259 Acc: 0.9711
# Elapsed 2054.59s, 52.68 s/epoch, 0.01 s/batch, ets 1106.32s
#
# Test set: Average loss: 0.2614, Accuracy: 9283/10000 (93%)
#
# Epoch: 39 Train Loss: 0.077128 Acc: 0.9705
# Elapsed 2105.39s, 52.63 s/epoch, 0.01 s/batch, ets 1052.70s
#
# Test set: Average loss: 0.2722, Accuracy: 9273/10000 (93%)
#
# Epoch: 40 Train Loss: 0.076072 Acc: 0.9716
# Elapsed 2156.66s, 52.60 s/epoch, 0.01 s/batch, ets 999.43s
#
# Test set: Average loss: 0.2691, Accuracy: 9260/10000 (93%)
#
# Epoch: 41 Train Loss: 0.069949 Acc: 0.9736
# Elapsed 2207.33s, 52.56 s/epoch, 0.01 s/batch, ets 946.00s
#
# Test set: Average loss: 0.2683, Accuracy: 9278/10000 (93%)
#
# Epoch: 42 Train Loss: 0.069487 Acc: 0.9742
# Elapsed 2257.95s, 52.51 s/epoch, 0.01 s/batch, ets 892.68s
#
# Test set: Average loss: 0.2882, Accuracy: 9255/10000 (93%)
#
# Epoch: 43 Train Loss: 0.070731 Acc: 0.9730
# Elapsed 2308.92s, 52.48 s/epoch, 0.01 s/batch, ets 839.61s
#
# Test set: Average loss: 0.2727, Accuracy: 9257/10000 (93%)
#
# Epoch: 44 Train Loss: 0.070915 Acc: 0.9737
# Elapsed 2359.42s, 52.43 s/epoch, 0.01 s/batch, ets 786.47s
#
# Test set: Average loss: 0.2728, Accuracy: 9273/10000 (93%)
#
# Epoch: 45 Train Loss: 0.068211 Acc: 0.9740
# Elapsed 2410.26s, 52.40 s/epoch, 0.01 s/batch, ets 733.56s
#
# Test set: Average loss: 0.2763, Accuracy: 9255/10000 (93%)
#
# Epoch: 46 Train Loss: 0.065505 Acc: 0.9751
# Elapsed 2460.98s, 52.36 s/epoch, 0.01 s/batch, ets 680.70s
#
# Test set: Average loss: 0.2861, Accuracy: 9244/10000 (92%)
#
# Epoch: 47 Train Loss: 0.065243 Acc: 0.9754
# Elapsed 2512.06s, 52.33 s/epoch, 0.01 s/batch, ets 628.02s
#
# Test set: Average loss: 0.2813, Accuracy: 9285/10000 (93%)
#
# Epoch: 48 Train Loss: 0.064394 Acc: 0.9759
# Elapsed 2562.65s, 52.30 s/epoch, 0.01 s/batch, ets 575.29s
#
# Test set: Average loss: 0.2727, Accuracy: 9270/10000 (93%)
#
# Epoch: 49 Train Loss: 0.058344 Acc: 0.9776
# Elapsed 2613.77s, 52.28 s/epoch, 0.01 s/batch, ets 522.75s
#
# Test set: Average loss: 0.2923, Accuracy: 9280/10000 (93%)
#
# Epoch: 50 Train Loss: 0.058978 Acc: 0.9784
# Elapsed 2664.11s, 52.24 s/epoch, 0.01 s/batch, ets 470.14s
#
# Test set: Average loss: 0.2799, Accuracy: 9277/10000 (93%)
#
# Epoch: 51 Train Loss: 0.059437 Acc: 0.9783
# Elapsed 2715.16s, 52.21 s/epoch, 0.01 s/batch, ets 417.72s
#
# Test set: Average loss: 0.2846, Accuracy: 9290/10000 (93%)
#
# Epoch: 52 Train Loss: 0.057094 Acc: 0.9785
# Elapsed 2766.31s, 52.19 s/epoch, 0.01 s/batch, ets 365.36s
#
# Test set: Average loss: 0.2883, Accuracy: 9274/10000 (93%)
#
# Epoch: 53 Train Loss: 0.056404 Acc: 0.9790
# Elapsed 2817.35s, 52.17 s/epoch, 0.01 s/batch, ets 313.04s
#
# Test set: Average loss: 0.2906, Accuracy: 9286/10000 (93%)
#
# Epoch: 54 Train Loss: 0.055484 Acc: 0.9785
# Elapsed 2868.18s, 52.15 s/epoch, 0.01 s/batch, ets 260.74s
#
# Test set: Average loss: 0.2934, Accuracy: 9284/10000 (93%)
#
# Epoch: 55 Train Loss: 0.054966 Acc: 0.9801
# Elapsed 2919.14s, 52.13 s/epoch, 0.01 s/batch, ets 208.51s
#
# Test set: Average loss: 0.2932, Accuracy: 9278/10000 (93%)
#
# Epoch: 56 Train Loss: 0.054215 Acc: 0.9798
# Elapsed 2969.84s, 52.10 s/epoch, 0.01 s/batch, ets 156.31s
#
# Test set: Average loss: 0.2869, Accuracy: 9271/10000 (93%)
#
# Epoch: 57 Train Loss: 0.051866 Acc: 0.9812
# Elapsed 3020.88s, 52.08 s/epoch, 0.01 s/batch, ets 104.17s
#
# Test set: Average loss: 0.3050, Accuracy: 9260/10000 (93%)
#
# Epoch: 58 Train Loss: 0.054293 Acc: 0.9801
# Elapsed 3072.99s, 52.08 s/epoch, 0.01 s/batch, ets 52.08s
#
# Test set: Average loss: 0.2897, Accuracy: 9285/10000 (93%)
#
# Epoch: 59 Train Loss: 0.048578 Acc: 0.9822
# Elapsed 3124.08s, 52.07 s/epoch, 0.01 s/batch, ets 0.00s
#
# Test set: Average loss: 0.3097, Accuracy: 9271/10000 (93%)
#
# Total time: 3129.75, Best Loss: 0.225

# %%
plot_loss_accuracy(train_loss=[train_loss_exp5], 
                   val_loss=[val_loss_exp5], 
                   train_acc=[train_acc_exp5], 
                   val_acc=[val_acc_exp5], 
                   labels=['BN-Drop'], 
                   colors=['purple'], 
                   model_sizes=['M'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# There is a mild improvement, if we add both. However, it can be tricky,  so always check each , separately.

# %% [markdown]
# ## <font style="color:green">3.5. Experiment 6: Data Augmentation [M]</font><a name="M-with_aug"></a>
#
# Finally, add Data augmentation. This should have a substantial effect on the validation curves  because we are actually training it on more data.
#
# **NOTE:** Data augmentation, unlike the other two techniques, is not added to the network with. This method increases the data while training, by creating transformations out of the original data. We thus use the `get_data` function to add `data_augmentation`. Pass the required argument to the function. Data augmentation generates the data passed to the training routine with. Do check out the code to see what types of augmentation we are doing.

# %%
model = MediumModel()
print(model)

optimizer, scheduler = get_optimizer_and_scheduler(model)

model, train_loss_exp6, train_acc_exp6, val_loss_exp6, val_acc_exp6 = main(model, 
                                                                           optimizer, 
                                                                           scheduler, 
                                                                           data_augmentation=True)

# %%
plot_loss_accuracy(train_loss=[train_loss_exp6], 
                   val_loss=[val_loss_exp6], 
                   train_acc=[train_acc_exp6], 
                   val_acc=[val_acc_exp6], 
                   labels=['Aug'], 
                   colors=['brown'], 
                   model_sizes=['M'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# You can see that there is a huge improvement in validation loss and accuracy.

# %% [markdown]
# ## <font style="color:green">3.6. Experiment 7: Data Augmentation with Batch-Norm and Dropout [M]</font><a name="M-with_Aug_and_BN_and_Drop"></a>
#
# Why stop at Data augmentation? Let us add Dropout as well as Batch Norm to the pipeline, and make it even more robust!

# %%
model = MediumModel(0.25, batch_norm=True)
print(model)

optimizer, scheduler = get_optimizer_and_scheduler(model)

model, train_loss_exp7, train_acc_exp7, val_loss_exp7, val_acc_exp7 = main(model, 
                                                                           optimizer, 
                                                                           scheduler, 
                                                                           data_augmentation=True)

# %%
plot_loss_accuracy(train_loss=[train_loss_exp7], 
                   val_loss=[val_loss_exp7], 
                   train_acc=[train_acc_exp7], 
                   val_acc=[val_acc_exp7], 
                   labels=['Aug-BN-Drop'], 
                   colors=['pink'], 
                   model_sizes=['M'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# # <font style="color:blue">4. Model 3: Large Model [L]</font><a name="Large"></a>
#
# In the  final step, let's take a larger model and see if we can further  improve the metrics.

# %%
class LargeModel(nn.Module):
    def __init__(self, dropout=0.0, batch_norm=False):
        super().__init__()

        # convolution layers
        if batch_norm:
            self._body = nn.Sequential(
                nn.Conv2d(in_channels=1, out_channels=64, kernel_size=5, padding=2),
                nn.BatchNorm2d(64),
                nn.ReLU(inplace=True),

                nn.Conv2d(in_channels=64, out_channels=64, kernel_size=5, padding=2),
                nn.BatchNorm2d(64),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2),

                nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
                nn.BatchNorm2d(128),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2),
                nn.Dropout(dropout)
            )
        else:
            self._body = nn.Sequential(
                nn.Conv2d(in_channels=1, out_channels=64, kernel_size=5, padding=2),
                nn.ReLU(inplace=True),

                nn.Conv2d(in_channels=64, out_channels=64, kernel_size=5, padding=2),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2),

                nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=2),
                nn.Dropout(dropout)
            )
            
        
        # Fully connected layers
        self._head = nn.Sequential(
            
            nn.Linear(in_features=128 * 7 * 7, out_features=2048), 
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            
            nn.Linear(in_features=2048, out_features=256), 
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            
            nn.Linear(in_features=256, out_features=10)
        )

    def forward(self, x):
        x = self._body(x)
        x = x.view(x.size()[0], -1)
        x = self._head(x)
        return x

# %% [markdown]
# ## <font style="color:green">4.1. Experiment 8: Data Augmentation With Batch-Norm and Dropout [L]</font><a name="L-with_Drop_Aug_BN"></a>

# %%
model = LargeModel(0.25, batch_norm=True)
print(model)

optimizer, scheduler = get_optimizer_and_scheduler(model)

model, train_loss_exp8, train_acc_exp8, val_loss_exp8, val_acc_exp8 = main(model, 
                                                                               optimizer, 
                                                                               scheduler, 
                                                                               data_augmentation=True)

# %%
plot_loss_accuracy(train_loss=[train_loss_exp8], 
                   val_loss=[val_loss_exp8], 
                   train_acc=[train_acc_exp8], 
                   val_acc=[val_acc_exp8], 
                   labels=['Aug-BN-Drop'], 
                   colors=['olive'], 
                   model_sizes=['L'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# # <font style="color:blue">5. Loss and Accuracy Plot of All Experiments</font><a name="plots"></a>

# %%
plot_loss_accuracy(train_loss=[train_loss_exp1, train_loss_exp2, train_loss_exp3, train_loss_exp4, 
                               train_loss_exp5, train_loss_exp6, train_loss_exp7, train_loss_exp8], 
                   val_loss=[val_loss_exp1, val_loss_exp2, val_loss_exp3, val_loss_exp4,
                             val_loss_exp5, val_loss_exp6, val_loss_exp7, val_loss_exp8], 
                   train_acc=[train_acc_exp1, train_acc_exp2, train_acc_exp3, train_acc_exp4, 
                              train_acc_exp5, train_acc_exp6, train_acc_exp7, train_acc_exp8], 
                   val_acc=[val_acc_exp1, val_acc_exp2, val_acc_exp3, val_acc_exp4, 
                            val_acc_exp5, val_acc_exp6, val_acc_exp7, val_acc_exp8], 
                   labels=['No Reg', 'No Reg', 'BN', 'Drop', 'BN-Drop', 'Aug', 'Aug-BN-Drop', 'Aug-BN-Drop'], 
                   colors=['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'olive'], 
                   model_sizes=['S', 'M', 'M', 'M', 'M', 'M', 'M', 'L'], 
                   loss_legend_loc='upper left', 
                   acc_legend_loc='best', 
                   legend_font = 12,
                   fig_size=(12, 24), 
                   sub_plot1=(2, 1, 1), 
                   sub_plot2=(2, 1, 2))

# %% [markdown]
# # <font style="color:blue">6. Conclusion</font><a name="conclusion"></a>
#
# Start with a simple model that overfits the training data.
#
# Then use different regularization techniques, optimizers and schedulers.
#
# If results are not satisfactory, change the model and experiment again.

# %% [markdown]
# # <font style="color:blue">Exercise</font><a name="exercise"></a>
#
# 1. Try with different Dropout values, plot curves to gain more insights on what happens.
#
#
#
# 2. Add more transforms to data augmentation <a href="https://pytorch.org/vision/stable/transforms.html" target="_blank">Check the complete list</a>.
#
#
# 3. Change the dataset to STL ( `torchvision.datasets.STL` ) and see the results (Note: You need to change the network accordingly).
